# %% [markdown]
# #### Outline
# 1. Data collection
# 2. Feature Engineering
# 3. Input Construction
# 4. GRU Modeling
# 5. GRU Model Evaluation

# %% [markdown]
# ## 1. Data collection - Individual Stocks

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

# %%
ticker = "CBA"

df = pd.read_csv("combined_stock_data.csv", parse_dates=['Date'])
stock_df = df[df['Name'] == ticker].copy()

# Sort by date
stock_df.sort_values(by='Date', inplace=True)

# Set index
stock_df.set_index('Date', inplace=True)


# Missing values
print("\n Missing values:")
print(stock_df.isnull().sum())  # Count missing values per column
stock_df.dropna(inplace=True)

# Check column and head
print(stock_df.columns)
print(stock_df.head())

# Check the number of rows
freq_counts = stock_df['Name'].value_counts()
print(freq_counts.describe())
# Out:
#  Missing values:
# Open      0
# High      0
# Low       0
# Close     0
# Volume    0
# Name      0
# dtype: int64
# Index(['Open', 'High', 'Low', 'Close', 'Volume', 'Name'], dtype='object')
#                  Open       High        Low      Close   Volume Name
# Date
# 2020-01-02  64.860162  65.209704  64.535007  64.933319  1416232  CBA
# 2020-01-03  65.819375  65.998211  65.234096  65.282867  1622784  CBA
# 2020-01-06  64.811385  64.933313  64.404942  64.843895  2129260  CBA
# 2020-01-07  65.697438  66.006332  65.177192  66.006332  2417468  CBA
# 2020-01-08  66.022597  66.046983  65.055261  65.762474  1719114  CBA
# count       1.0
# mean     1266.0
# std         NaN
# min      1266.0
# 25%      1266.0
# 50%      1266.0
# 75%      1266.0
# max      1266.0
# Name: count, dtype: float64

# %% [markdown]
# ## 📊 2. Features Engineering
#
# These features combine classic time series lags, trend indicators, momentum oscillators, and volatility metrics.
# Grouped below by functional type, they provide rich information for both interpretable models and deep learning models like GRU.
#
# ---
#
# ### 🕒 Lag Features
# Understand **short-term behavior** via lags and returns.
#
# | Column Name     | Description |
# |-----------------|-------------|
# | **price_lag1**   | Closing price from 1 day ago – captures immediate price momentum |
# | **price_lag2**   | Closing price from 2 days ago – extends short-term memory |
# | **return_lag1**  | Percentage return from 1 day ago – normalized price change (%) |
#
# ---
#
# ### 📈 Trend Indicators
# Capture **trend direction and reversals** using SMA, EMA, and price deviation.
#
# | Column Name     | Description |
# |-----------------|-------------|
# | **SMA_5**        | 5-day Simple Moving Average – short-term trend average |
# | **SMA_20**       | 20-day Simple Moving Average – long-term trend reference |
# | **EMA_20**       | 20-day Exponential Moving Average – reacts faster to recent prices |
# | **norm_price**   | Price deviation (%) from 20-day MA – normalized position relative to trend |
#
# ---
#
# ### 🔄 Momentum Indicators
# Measure **momentum and overbought/oversold conditions** via RSI and MACD.
#
# | Column Name     | Description |
# |-----------------|-------------|
# | **RSI_14**       | 14-day Relative Strength Index – momentum oscillator (0–100 scale). Overbought if >70, Oversold if <30 |
# | **MACD**         | Moving Average Convergence Divergence – difference between EMA(12) and EMA(26), indicates momentum direction |
# | **MACD_signal**  | 9-day EMA of MACD – signal line used for MACD crossover buy/sell decisions |
#
# ---
#
# ### 🌊 Volatility Features
# Quantify **volatility and risk** using standard deviation and volatility ratios.
#
# | Column Name       | Description |
# |-------------------|-------------|
# | **roll_std5**      | 5-day rolling standard deviation – short-term volatility indicator |
# | **volatility_5**   | Standard deviation of 5-day returns – recent volatility measure |
# | **volatility_20**  | Standard deviation of 20-day returns – longer-term volatility context |
# | **vol_ratio**      | Ratio of short-term to long-term volatility (`vol_5 / vol_20`) – reflects market stability shifts |

# %%
import numpy as np

# %%
# Compute daily returns as percentage change in closing price
stock_df['returns'] = stock_df['Close'].pct_change() * 100

# ------------------------------------------
# 🕒 Lag Features
# ------------------------------------------
stock_df['price_lag1'] = stock_df['Close'].shift(1)
stock_df['price_lag2'] = stock_df['Close'].shift(2)
stock_df['return_lag1'] = stock_df['returns'].shift(1)

# ------------------------------------------
# 📈 Trend Indicators
# ------------------------------------------
stock_df['SMA_5'] = stock_df['Close'].rolling(window=5).mean()
stock_df['SMA_20'] = stock_df['Close'].rolling(window=20).mean()
stock_df['EMA_20'] = stock_df['Close'].ewm(span=20, adjust=False).mean()
stock_df['norm_price'] = (stock_df['Close'] - stock_df['SMA_20']) / stock_df['SMA_20'] * 100

# ------------------------------------------
# 🔄 Momentum Indicators
# ------------------------------------------

# RSI (14-day)
delta = stock_df['Close'].diff()
gain = (delta.where(delta > 0, 0)).fillna(0)
loss = (-delta.where(delta < 0, 0)).fillna(0)

avg_gain = gain.rolling(window=14).mean()
avg_loss = loss.rolling(window=14).mean()

rs = avg_gain / avg_loss
stock_df['RSI_14'] = 100 - (100 / (1 + rs))

# MACD and Signal Line
ema_12 = stock_df['Close'].ewm(span=12, adjust=False).mean()
ema_26 = stock_df['Close'].ewm(span=26, adjust=False).mean()
stock_df['MACD'] = ema_12 - ema_26
stock_df['MACD_signal'] = stock_df['MACD'].ewm(span=9, adjust=False).mean()

# ------------------------------------------
# 🌊 Volatility Features
# ------------------------------------------
stock_df['roll_std5'] = stock_df['Close'].rolling(window=5).std()
stock_df['volatility_5'] = stock_df['returns'].rolling(window=5).std()
stock_df['volatility_20'] = stock_df['returns'].rolling(window=20).std()
stock_df['vol_ratio'] = stock_df['volatility_5'] / stock_df['volatility_20'].replace(0, np.nan)

# %%
# Missing values
print("\n Missing values:")
print(stock_df.isnull().sum())
# Out:
#  Missing values:
# Open              0
# High              0
# Low               0
# Close             0
# Volume            0
# Name              0
# returns           1
# price_lag1        1
# price_lag2        2
# return_lag1       2
# SMA_5             4
# SMA_20           19
# EMA_20            0
# norm_price       19
# RSI_14           13
# MACD              0
# MACD_signal       0
# roll_std5         4
# volatility_5      5
# volatility_20    20
# vol_ratio        20
# dtype: int64

# %% [markdown]
# It's normal for rolling and shift-based indicators to have NaN values in the initial rows, since they require **past data** to compute.
#
# Especially for models like GRU or CNN where the sequence order is important,
# it's common practice to **drop** those initial rows with missing values before training the model.

# %%
stock_df.dropna(inplace=True)
print("Final shape after dropping NaNs:", stock_df.shape)
# Out:
# Final shape after dropping NaNs: (1246, 21)

# %%
import matplotlib.pyplot as plt

# %%
# ----------------------------------------
# 1. Price with SMA & EMA - Helps identify short- and long-term trend movements
# ----------------------------------------
plt.figure(figsize=(14, 6))
plt.plot(stock_df['Close'], label='Close Price', color='black')
plt.plot(stock_df['SMA_20'], label='SMA 20', linestyle='--')
plt.plot(stock_df['EMA_20'], label='EMA 20', linestyle='-.')
plt.title('Close Price with SMA and EMA')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.tight_layout()
plt.show()

# ----------------------------------------
# 2. RSI - Detects potential overbought and oversold conditions for timing entries/exits
# ----------------------------------------
plt.figure(figsize=(14, 4))
plt.plot(stock_df['RSI_14'], label='RSI 14', color='purple')
plt.axhline(70, color='red', linestyle='--', label='Overbought (70)')
plt.axhline(30, color='green', linestyle='--', label='Oversold (30)')
plt.title('RSI (Relative Strength Index)')
plt.xlabel('Date')
plt.ylabel('RSI')
plt.legend()
plt.tight_layout()
plt.show()

# ----------------------------------------
# 3. MACD - Highlights possible trend reversal signals through line crossovers
# ----------------------------------------
plt.figure(figsize=(14, 5))
plt.plot(stock_df['MACD'], label='MACD', color='blue')
plt.plot(stock_df['MACD_signal'], label='Signal Line', color='orange')
plt.axhline(0, color='gray', linestyle='--')
plt.title('MACD and Signal Line')
plt.xlabel('Date')
plt.ylabel('MACD Value')
plt.legend()
plt.tight_layout()
plt.show()

# ----------------------------------------
# 4. Volatility: rolling std and volatility ratio - Reveals market instability and periods of sharp fluctuations
# ----------------------------------------
plt.figure(figsize=(14, 5))
plt.plot(stock_df['volatility_5'], label='Volatility (5-day)', color='teal')
plt.plot(stock_df['volatility_20'], label='Volatility (20-day)', color='coral')
plt.title('Short vs Long-Term Volatility')
plt.xlabel('Date')
plt.ylabel('Volatility')
plt.legend()
plt.tight_layout()
plt.show()

plt.figure(figsize=(14, 4))
plt.plot(stock_df['vol_ratio'], label='Volatility Ratio (5d/20d)', color='brown')
plt.title('Volatility Ratio (5-day / 20-day)')
plt.xlabel('Date')
plt.ylabel('Ratio')
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# #### 📊 Interpretation of Technical Indicator Visualizations
#
# ---
#
# **📈 1. Close Price with SMA and EMA**
# - Overall, the stock shows an upward trend from 2020 to 2024.
# - The SMA and EMA lines closely follow each other. When the price is above both lines, it generally indicates a bullish trend; when it's below, it suggests a bearish trend.
#
# ---
#
# **🔄 2. RSI (Relative Strength Index)**
# - RSI values above 70 indicate overbought conditions; below 30 indicate oversold conditions.
# - A potential **buy signal** occurs when RSI rebounds near 30, and a **sell signal** when RSI drops from levels near 70.
#
# ---
#
# **💡 3. MACD and Signal Line**
# - A **bullish crossover** (MACD crossing above the Signal Line) may suggest a buy signal.
# - A **bearish crossover** (MACD crossing below the Signal Line) may suggest a sell signal.
# - MACD values above 0 indicate upward momentum, while values below 0 suggest downward momentum.
#
# ---
#
# **🌊 4. Short vs Long-Term Volatility**
# - A significant spike in early 2020 likely reflects heightened market instability (e.g., COVID-19 impact).
# - Afterward, volatility remains relatively low, with occasional event-driven spikes.
#
# ---
#
# **📊 5. Volatility Ratio (5-day / 20-day)**
# - A ratio above 1 suggests that short-term volatility is higher than long-term volatility.
# - Spikes near 2.0 indicate sudden short-term market turbulence, potentially triggered by news, events, or sharp price movements.
# - Useful for identifying abnormal market conditions that may cause sensitive reactions in predictive models.

# %%
# Create figure and subplots
plt.figure(figsize=(14, 8))

# RSI Plot
plt.subplot(2, 1, 2)
plt.plot(df['Date'], df['RSI_14'], label='RSI (14)', color='purple')
plt.axhline(70, color='red', linestyle='--', label='Overbought (70)')
plt.axhline(30, color='green', linestyle='--', label='Oversold (30)')
plt.title("RSI (14)")
plt.xlabel("Date")
plt.ylabel("RSI")
plt.grid(True)
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# The RSI fluctuates mostly between 30 and 70, but there are multiple peaks and troughs hitting the extremes.

# %%
plt.figure(figsize=(14, 6))

# Plot MACD and Signal Line
plt.plot(df['Date'], df['MACD'], label='MACD', color='blue')
plt.plot(df['Date'], df['MACD_signal'], label='Signal Line', color='orange')

# Optional: zero line
plt.axhline(0, color='gray', linestyle='--', linewidth=1)

plt.title("MACD and Signal Line")
plt.xlabel("Date")
plt.ylabel("Value")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# Since around 2020, the MACD has generally been rising, indicating strengthening upward momentum, with more frequent and larger fluctuations in recent years.

# %% [markdown]
# ## 3. Input Construction
#
# ### Objective
# Use the past **N day** of time-series as input **X**, and predict either the **closing price D days ahead** or the **price direction (up/down)** as output **Y**.
#
# ### Example Setting
# - `N = 30`: Use the past 30 days of data as input
# - `D = 5`: Predict the closing price (or direction) 5 days into the future
#
# ### Required Features
# To construct effective input sequences, we include the following engineered features:
#
# - Lag-based prices and returns: `price_lag1`, `return_lag1`, etc.
# - Trend indicators: `SMA_5`, `EMA_20`, `norm_price`
# - Momentum indicators: `RSI_14`, `MACD`, `MACD_signal`
# - Volatility metrics: `volatility_5`, `vol_ratio`
#
# The features are normalized or scaled where necessary to ensure stability in model training.

# %%
def create_sequences(data, target_col, N=30, D=5, task='regression'):
    """
    Create input-output sequences for time-series models like GRU or CNN.

    Parameters:
    - data: pandas DataFrame with time-series features
    - target_col: column name to be predicted (e.g., 'Close')
    - N: number of days to use as input (sequence length)
    - D: number of days ahead to predict
    - task: 'regression' or 'classification'

    Returns:
    - X: 3D numpy array (samples, N, features)
    - y: 1D or 2D numpy array of targets
    """

    X = []
    y = []

    features = data.drop(columns=[target_col]).values
    target = data[target_col].values

    for i in range(len(data) - N - D + 1):
        X_seq = features[i:i+N]
        if task == 'regression':
            y_label = target[i+N+D-1]  # Predict D days ahead closing price
        elif task == 'classification':
            y_label = 1 if target[i+N+D-1] > target[i+N-1] else 0  # Price up or down
        else:
            raise ValueError("Task must be 'regression' or 'classification'")

        X.append(X_seq)
        y.append(y_label)

    return np.array(X), np.array(y)

# %% [markdown]
# Ensure that only historical data is used to predict future values, in line with the principle of time series forecasting.
# - **X**: The past **N days** of input data (e.g., from index `i` to `i+N-1`, representing up to time **t**
# - **y**: The target value at **D days after** the input window (i.e., at index `i+N+D-1`), representing a **future time step to be predicted**

# %%
feature_cols = [
    'price_lag1', 'price_lag2', 'return_lag1',
    'SMA_5', 'SMA_20', 'EMA_20', 'norm_price',
    'RSI_14', 'MACD', 'MACD_signal',
    'volatility_5', 'volatility_20', 'vol_ratio'
]

target_col = 'Close'  # For regression
seq_df = stock_df[feature_cols + [target_col]].dropna().copy()

# Create sequences
X, y = create_sequences(seq_df, target_col=target_col, N=30, D=5, task='regression')

print("✅ Sequences created:")
print("X shape:", X.shape)  # (samples, 30, features)
print("y shape:", y.shape)  # (samples,)
# Out:
# ✅ Sequences created:
# X shape: (1212, 30, 13)
# y shape: (1212,)

# %% [markdown]
# ## 4. GRU Modeling

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import GRU, Dense, Dropout
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.optimizers import Adam
# Out:
# WARNING:tensorflow:From C:\Users\jiyoo\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %% [markdown]
# ### Data Preprocessing

# %%
# Feature scaling (optional but recommended for GRU)
X_reshaped = X.reshape(-1, X.shape[-1])  # (1212*30, 13)
X_scaler = MinMaxScaler()
X_scaled = X_scaler.fit_transform(X_reshaped)
X_scaled = X_scaled.reshape(X.shape)  # (1212, 30, 13)

# y scaling (for regression)
y = y.reshape(-1, 1)
y_scaler = MinMaxScaler()
y_scaler.fit(y)  # fit only once
y_scaled = y_scaler.transform(y)  # transform separately

# %% [markdown]
# ### Train/Validation Split for Time Series

# %%
split_index = int(len(X_scaled) * 0.8)

# Training set: the first 80% of the sequence
X_train = X_scaled[:split_index]
y_train = y_scaled[:split_index]

# Validation set: the most recent 20%
X_val = X_scaled[split_index:]
y_val = y_scaled[split_index:]

print("X_train shape:", X_train.shape)
print("X_val shape:", X_val.shape)
# Out:
# X_train shape: (969, 30, 13)
# X_val shape: (243, 30, 13)

# %% [markdown]
# - The temporal sequence must not be broken.
# - **Using recent data as validation** allows us to test how the model would behave on unseen, future-like data.
# - Once the model architecture is reasonably finaised, expand to **TimeSeriesSplit** for evaluating performance stability and implementing cross-validated GRU training.

# %% [markdown]
# ### Build GRU model

# %%
# Set input dimensions
timesteps = X_train.shape[1]  # ➜ 30 (N-day input window)
features = X_train.shape[2]   # ➜ 13 (number of input features per time step)

# Build GRU model
gru_model = Sequential([
    GRU(64, input_shape=(timesteps, features), return_sequences=False), # Encodes the input sequence into a 64-dimensional representation
    Dropout(0.2), # Randomly drops a portion of the units during training to prevent overfitting
    Dense(32, activation='relu'), # Fully connected layer
    Dense(1)  # Regression output
])

gru_model.compile(
    optimizer=Adam(learning_rate=0.001),
    loss='mse',
    metrics=['mae']
)

gru_model.summary()
# Out:
# WARNING:tensorflow:From C:\Users\jiyoo\anaconda3\Lib\site-packages\keras\src\layers\rnn\gru.py:144: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 64)                15168
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense (Dense)               (None, 32)                2080
#
#  dense_1 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 17281 (67.50 KB)
# Trainable params: 17281 (67.50 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### Train GRU model

# %% [markdown]
# - `loss`: Mean Squared Error (MSE) on the training set
# - `val_loss`: Mean Squared Error (MSE) on the validation set
#
# **🧠 Interpretation Guide**
#
# | Pattern                | Interpretation                                                                 |
# |------------------------|---------------------------------------------------------------------------------|
# | `loss ↓`, `val_loss ↓` | The model is learning well and improving over time                            |
# | `loss ↓`, `val_loss ↑` | Possible overfitting – the model fits training data well but does not generalize  |
# | `loss ≈ val_loss`, high values | Stable learning but performance still has room for improvement               |
#
#
# **✅ MAE (Mean Absolute Error)**
#
# If `metrics=['mae']` is specified during model compilation,
# then `val_mae` represents the **average absolute difference** between predicted and actual values on the validation set.
#
# **📈 Predicted vs Actual Plot Patterns**
#
# | Pattern                                  | Interpretation                                                              |
# |------------------------------------------|------------------------------------------------------------------------------|
# | Lines closely overlap                    | Strong prediction performance                                             |
# | Trend is correct but scale is off       | Scaling or normalization might need adjustment                             |
# | Predictions are flat or unresponsive     | Model may be too simple or input sequence too short                        |
# | Predictions fluctuate excessively        | Possible overfitting or noisy data                                          |

# %%
history = gru_model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=50,
    batch_size=32,
    verbose=1
)
# Out:
# Epoch 1/50
# WARNING:tensorflow:From C:\Users\jiyoo\anaconda3\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\jiyoo\anaconda3\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 31/31 [==============================] - 5s 39ms/step - loss: 0.0272 - mae: 0.1198 - val_loss: 0.0091 - val_mae: 0.0744
# Epoch 2/50
# 31/31 [==============================] - 0s 9ms/step - loss: 0.0040 - mae: 0.0495 - val_loss: 0.0117 - val_mae: 0.0921
# Epoch 3/50
# 31/31 [==============================] - 0s 9ms/step - loss: 0.0030 - mae: 0.0430 - val_loss: 0.0125 - val_mae: 0.0985
# Epoch 4/50
# 31/31 [==============================] - 0s 9ms/step - loss: 0.0024 - mae: 0.0378 - val_loss: 0.0094 - val_mae: 0.0847
# Epoch 5/50
# 31/31 [==============================] - 0s 9ms/step - loss: 0.0021 - mae: 0.0363 - val_loss: 0.0102 - val_mae: 0.0914
# Epoch 6/50
# 31/31 [==============================] - 0s 9ms/step - loss: 0.0019 - mae: 0.0345 - val_loss: 0.0119 - val_mae: 0.0995
# Epoch 7/50
# 31/31 [==============================] - 0s 9ms/step - loss: 0.0017 - mae: 0.0323 - val_loss: 0.0086 - val_mae: 0.0828
# Epoch 8/50
# 31/31 [==============================] - 0s 9ms/step - loss: 0.0015 - mae: 0.0304 - val_loss: 0.0108 - val_mae: 0.0947
# Epoch 9/50
# 31/31 [==============================] - 0s 9ms/step - loss: 0.0016 - mae: 0.0314 - val_loss: 0.0089 - val_mae: 0.0844
# Epoch 10/50
# 31/31 [==============================] - 0s 9ms/step - loss: 0.0015 - mae: 0.0305 - val_loss: 0.0149 - val_mae: 0.1137
# Epoch 11/50
# 31/31 [==============================] - 0s 9ms/step - loss: 0.0014 - mae: 0.0290 - val_loss: 0.0088 - val_mae: 0.0845
# Epoch 12/50
# 31/31 [==============================] - 0s 9ms/step - loss: 0.0012 - mae: 0.0274 - val_loss: 0.0096 - val_mae: 0.0885
# Epoch 13/50
# 31/31 [==============================] - 0s 9ms/step - loss: 0.0013 - mae: 0.0283 - val_loss: 0.0147 - val_mae: 0.1130
# Epoch 14/50
# 31/31 [==============================] - 0s 9ms/step - loss: 0.0013 - mae: 0.0280 - val_loss: 0.0142 - val_mae: 0.1105
# Epoch 15/50
# 31/31 [==============================] - 0s 9ms/step - loss: 0.0012 - mae: 0.0271 - val_loss: 0.0100 - val_mae: 0.0906
# Epoch 16/50
# 31/31 [==============================] - 0s 9ms/step - loss: 0.0010 - mae: 0.0247 - val_loss: 0.0110 - val_mae: 0.0948
# Epoch 17/50
# 31/31 [==============================] - 0s 10ms/step - loss: 0.0011 - mae: 0.0260 - val_loss: 0.0087 - val_mae: 0.0829
# Epoch 18/50
# 31/31 [==============================] - 0s 10ms/step - loss: 0.0011 - mae: 0.0271 - val_loss: 0.0130 - val_mae: 0.1049
# Epoch 19/50
# 31/31 [==============================] - 0s 10ms/step - loss: 0.0011 - mae: 0.0254 - val_loss: 0.0084 - val_mae: 0.0815
# Epoch 20/50
# 31/31 [==============================] - 0s 10ms/step - loss: 0.0011 - mae: 0.0255 - val_loss: 0.0106 - val_mae: 0.0937
# Epoch 21/50
# 31/31 [==============================] - 0s 11ms/step - loss: 0.0010 - mae: 0.0250 - val_loss: 0.0043 - val_mae: 0.0547
# Epoch 22/50
# 31/31 [==============================] - 0s 11ms/step - loss: 0.0010 - mae: 0.0255 - val_loss: 0.0139 - val_mae: 0.1094
# Epoch 23/50
# 31/31 [==============================] - 0s 10ms/step - loss: 9.4378e-04 - mae: 0.0239 - val_loss: 0.0109 - val_mae: 0.0958
# Epoch 24/50
# 31/31 [==============================] - 0s 10ms/step - loss: 0.0010 - mae: 0.0247 - val_loss: 0.0119 - val_mae: 0.1004
# Epoch 25/50
# 31/31 [==============================] - 0s 10ms/step - loss: 9.5808e-04 - mae: 0.0244 - val_loss: 0.0092 - val_mae: 0.0869
# Epoch 26/50
# 31/31 [==============================] - 0s 9ms/step - loss: 8.6464e-04 - mae: 0.0227 - val_loss: 0.0104 - val_mae: 0.0929
# Epoch 27/50
# 31/31 [==============================] - 0s 9ms/step - loss: 8.4689e-04 - mae: 0.0231 - val_loss: 0.0101 - val_mae: 0.0918
# Epoch 28/50
# 31/31 [==============================] - 0s 10ms/step - loss: 8.0687e-04 - mae: 0.0222 - val_loss: 0.0104 - val_mae: 0.0934
# Epoch 29/50
# 31/31 [==============================] - 0s 9ms/step - loss: 8.4510e-04 - mae: 0.0228 - val_loss: 0.0066 - val_mae: 0.0721
# Epoch 30/50
# 31/31 [==============================] - 0s 9ms/step - loss: 8.1275e-04 - mae: 0.0220 - val_loss: 0.0130 - val_mae: 0.1055
# Epoch 31/50
# 31/31 [==============================] - 0s 9ms/step - loss: 7.6399e-04 - mae: 0.0215 - val_loss: 0.0135 - val_mae: 0.1078
# Epoch 32/50
# 31/31 [==============================] - 0s 9ms/step - loss: 7.9887e-04 - mae: 0.0221 - val_loss: 0.0088 - val_mae: 0.0845
# Epoch 33/50
# 31/31 [==============================] - 0s 10ms/step - loss: 7.8330e-04 - mae: 0.0219 - val_loss: 0.0108 - val_mae: 0.0952
# Epoch 34/50
# 31/31 [==============================] - 0s 10ms/step - loss: 8.6733e-04 - mae: 0.0233 - val_loss: 0.0076 - val_mae: 0.0777
# Epoch 35/50
# 31/31 [==============================] - 0s 9ms/step - loss: 8.9240e-04 - mae: 0.0235 - val_loss: 0.0076 - val_mae: 0.0790
# Epoch 36/50
# 31/31 [==============================] - 0s 10ms/step - loss: 9.0884e-04 - mae: 0.0233 - val_loss: 0.0111 - val_mae: 0.0967
# Epoch 37/50
# 31/31 [==============================] - 0s 13ms/step - loss: 7.8128e-04 - mae: 0.0222 - val_loss: 0.0143 - val_mae: 0.1114
# Epoch 38/50
# 31/31 [==============================] - 0s 9ms/step - loss: 7.8652e-04 - mae: 0.0217 - val_loss: 0.0125 - val_mae: 0.1031
# Epoch 39/50
# 31/31 [==============================] - 0s 9ms/step - loss: 7.6813e-04 - mae: 0.0216 - val_loss: 0.0086 - val_mae: 0.0835
# Epoch 40/50
# 31/31 [==============================] - 0s 9ms/step - loss: 8.1926e-04 - mae: 0.0224 - val_loss: 0.0104 - val_mae: 0.0930
# Epoch 41/50
# 31/31 [==============================] - 0s 9ms/step - loss: 7.3027e-04 - mae: 0.0208 - val_loss: 0.0089 - val_mae: 0.0869
# Epoch 42/50
# 31/31 [==============================] - 0s 10ms/step - loss: 7.8835e-04 - mae: 0.0220 - val_loss: 0.0093 - val_mae: 0.0872
# Epoch 43/50
# 31/31 [==============================] - 0s 9ms/step - loss: 7.5467e-04 - mae: 0.0212 - val_loss: 0.0098 - val_mae: 0.0907
# Epoch 44/50
# 31/31 [==============================] - 0s 10ms/step - loss: 7.8314e-04 - mae: 0.0218 - val_loss: 0.0093 - val_mae: 0.0888
# Epoch 45/50
# 31/31 [==============================] - 0s 10ms/step - loss: 7.1505e-04 - mae: 0.0209 - val_loss: 0.0114 - val_mae: 0.0994
# Epoch 46/50
# 31/31 [==============================] - 0s 11ms/step - loss: 7.2222e-04 - mae: 0.0208 - val_loss: 0.0085 - val_mae: 0.0827
# Epoch 47/50
# 31/31 [==============================] - 0s 9ms/step - loss: 7.4063e-04 - mae: 0.0216 - val_loss: 0.0058 - val_mae: 0.0671
# Epoch 48/50
# 31/31 [==============================] - 0s 9ms/step - loss: 7.1655e-04 - mae: 0.0209 - val_loss: 0.0124 - val_mae: 0.1042
# Epoch 49/50
# 31/31 [==============================] - 0s 9ms/step - loss: 7.9199e-04 - mae: 0.0220 - val_loss: 0.0119 - val_mae: 0.1012
# Epoch 50/50
# 31/31 [==============================] - 0s 9ms/step - loss: 7.4130e-04 - mae: 0.0213 - val_loss: 0.0145 - val_mae: 0.1131

# %%
# Predict
y_pred = gru_model.predict(X_val)

# Inverse transform
y_pred = y_scaler.inverse_transform(y_pred)
y_val = y_scaler.inverse_transform(y_val)

index = stock_df.index[-len(y_val):]
# Out:
# 8/8 [==============================] - 1s 3ms/step

# %%
# Visualise
plt.figure(figsize=(12, 5))
plt.plot(index, y_val, label='True')
plt.plot(index, y_pred, label='Predicted (GRU)', linestyle='--')
plt.title('GRU Forecast vs True')
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# #### ✅ GRU Training Performance Summary
#
# | Metric           | Interpretation |
# |------------------|----------------|
# | **loss (Train MSE)**     | Started at **0.0496**, dropped to **0.00074** → large reduction in training error |
# | **val_loss (Validation MSE)** | Started at **0.0654**, reached a minimum of **0.0045** at **epoch 20**, later oscillated |
# | **val_mae (Validation MAE)**  | Averaged between **0.057–0.102**, which corresponds to small deviations from true prices |
#
# ---
#
# **🔍 Training Curve Behavior**
#
# **Epochs 1–20:**
#
# - Both `loss` and `val_loss` decreased rapidly, indicating successful learning.
# - Best validation performance at **epoch 20** (`val_loss = 0.0045`, `val_mae = 0.0576`).
#
# **Epochs 20–50:**
#
# - Mild oscillations in validation loss observed.
# - No signs of severe overfitting.
# - Performance plateaued, indicating a stable but potentially under-capacity model.
#
# ---
#
# **📈 Quantitative Insight**
#
# - **val_mae** hovers around **0.06–0.10**, meaning on average the model’s prediction deviates from the true price by that amount.
# - Given that the CBA stock price ranges between **100–160**, this implies a **relative error of approximately 0.06%–0.10%**, which is quite strong.
#
# ✅ The model successfully learns the general trend and magnitude, but there may still be room to **further reduce bias or enhance reactivity**.

# %% [markdown]
# #### ✅ GRU Training Performance Summary
#
# | Metric           | Interpretation |
# |------------------|----------------|
# | **loss (Train MSE)**     | Started at **0.0496**, dropped to **0.00074** → large reduction in training error |
# | **val_loss (Validation MSE)** | Started at **0.0654**, reached a minimum of **0.0045** at **epoch 20**, later oscillated |
# | **val_mae (Validation MAE)**  | Averaged between **0.057–0.102**, which corresponds to small deviations from true prices |
#
# ---
#
# **🔍 Training Curve Behavior**
#
# **Epochs 1–20:**
#
# - Both `loss` and `val_loss` decreased rapidly, indicating successful learning.
# - Best validation performance at **epoch 20** (`val_loss = 0.0045`, `val_mae = 0.0576`).
#
# **Epochs 20–50:**
#
# - Mild oscillations in validation loss observed.
# - No signs of severe overfitting.
# - Performance plateaued, indicating a stable but potentially under-capacity model.
#
# ---
#
# **📈 Quantitative Insight**
#
# - **val_mae** hovers around **0.06–0.10**, meaning on average the model’s prediction deviates from the true price by that amount.
# - Given that the CBA stock price ranges between **100–160**, this implies a **relative error of approximately 0.06%–0.10%**, which is quite strong.
#
# ✅ The model successfully learns the general trend and magnitude, but there may still be room to **further reduce bias or enhance reactivity**.

# %% [markdown]
# ### Prediction and Visualisation
# *The model trains on normalised data above, while interpretation is done on the original scale.*
#
# *Make sure to use `X` and `y` generated after `.dropna()`, as mismatched lengths between `y_val` and `y_pred` can cause errors.*
#
# *To zoom in, we can plot a subset like `plt.plot(y_val[:100])` for better visual clarity.*

# %%
# Prediction
gru_y_pred = gru_model.predict(gru_X_val)

# Inverse transform
gru_y_pred = gru_y_scaler.inverse_transform(gru_y_pred)
gru_y_val = gru_y_scaler.inverse_transform(gru_y_val)

gru_index = stock_df.index[-len(gru_y_val):]
# Out:
# 8/8 [==============================] - 1s 4ms/step

# %%
# Visualisation
plt.figure(figsize=(12, 5))
plt.plot(gru_index, gru_y_val, label='True')
plt.plot(gru_index, gru_y_pred, label='Predicted')
plt.title('GRU Forecast vs True')
plt.xlabel('Time Step')
plt.ylabel('Close Price')
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# | Aspect               | Insight |
# |----------------------|---------|
# | 📈 **Trend alignment** | The predicted line follows the general upward/downward trends of the true prices → indicates the model has learned directional dynamics well |
# | 🔻 **Undershooting**   | The predicted values are consistently lower than the actual prices → might suggest bias or underfitting |
# | ⚖️ **Smoothness**       | Predictions are smoother than actuals → typical of neural networks minimizing MSE |
#
# To improve:
# - Try deeper GRU layers
# - Include more predictive features
# - Experiment with post-processing (e.g., rescaling or boosting techniques)

# %%
plt.figure(figsize=(12, 3))
plt.plot(gru_y_val - gru_y_pred, label='Prediction Error')
plt.title('Prediction Error (True - Predicted)')
plt.xlabel('Time Step')
plt.ylabel('Error')
plt.axhline(0, color='gray', linestyle='--')
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 5. GRU Model Evaluation

# %% [markdown]
# ### 5-1. Quantitative Evaluation
# *While we've already reviewed common metrics like **loss, MAE, and val_loss**, it's helpful to include additional evaluation metrics to get a more complete picture of model performance.*
#
# - **RMSE (Root Mean Squared Error)**: Measures the square root of the average squared difference between predicted and actual values. Penalizes large errors more heavily. A lower RMSE indicates better model accuracy.
# - **MAPE (Mean Absolute Percentage Error)**: Expresses prediction error as a percentage of the actual values. It shows, on average, how far off the predictions are in relative terms. Lower is better.
# - **$R^2$ Score (Coefficient of Determination)**: Represents how well the model explains the variance in the target variable. Ranges from 0 to 1 (closer to 1 is better). A negative value means the model performs worse than a horizontal line (mean predictor).

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error, r2_score

# %%
gru_rmse = np.sqrt(mean_squared_error(y_val, y_pred))
gru_mae = mean_absolute_error(y_val, y_pred)
gru_mape = mean_absolute_percentage_error(y_val, y_pred)
gru_r2 = r2_score(y_val, y_pred)

print("📊 GRU Performance:")
print(f"RMSE: {gru_rmse:.4f}")
print(f"MAE: {gru_mae:.4f}")
print(f"MAPE: {gru_mape:.4%}")
print(f"R² Score: {gru_r2:.4f}")
# Out:
# 📊 GRU Performance:
# RMSE: 13.6830
# MAE: 12.8662
# MAPE: 9.8689%
# R² Score: 0.1787

# %% [markdown]
# - **RMSE**: `11.15` → On average, predictions deviate from true values by about 11 units.
# - **MAE**: `10.13` → Indicates a relatively low absolute error.
# - **MAPE**: `7.70%` → On average, predictions differ from actual values by 7.7%.
# - **R² Score**: `0.4546` → The model explains only about **45%** of the variance in the target values.
#
# The basic GRU captures overall price trends but still shows signs of **underfitting**. While it models the directional pattern, it lacks precision in predicting exact values.
#
# **🛠️ Potential Directions for Model Improvement**
#
# | Direction              | Description |
# |------------------------|-------------|
# | 🔁 **Model Architecture Tuning** | Try deeper GRU layers, increase hidden size, or adjust dropout rates |
# | ➕ **Feature Expansion**          | Add more technical indicators or market-related variables (e.g., volume change rate, Bollinger Bands) |
# | 🔍 **Hyperparameter Tuning**     | Optimize learning rate, batch size, sequence length, etc. |
# | 🔀 **Hybrid Architectures**      | Explore GRU combined with Attention mechanisms or CNN-GRU hybrid models |
# | 🔧 **Target Variable Adjustment**| Instead of predicting absolute price, consider forecasting price changes or direction (i.e., classification) |

# %% [markdown]
# ### 5-2. Model Enhancements
#
# - 🔁 **Stacked GRU**: Enables deeper learning of temporal patterns by stacking multiple GRU layers.
# - 🔀 **CNN+GRU Hybrid**: Use CNN layers to extract local features, followed by GRU to model sequential dependencies.
# - 🔬 **Hyperparameter Tuning**: Experiment with different values for hidden size, dropout rate, learning rate, and other training parameters.

# %% [markdown]
# - GRU_model: GRU(64) ➝ Dropout ➝ Dense(32, relu) ➝ Dense(1)
#     - In a single-layer GRU architecture, Dense(32, relu) layer helps enhance the model's ability to capture nonlinear feature interactions.
# - Stacked_GRU_model: GRU(64, return_sequences=True) ➝ GRU(32) ➝ Dropout ➝ Dense(1)
#     - The two GRU layers themselves already handle complex nonlinear transformations effectively.

# %%
# Feature scaling 
X_scaler = MinMaxScaler()
X_scaled = X_scaler.fit_transform(X_reshaped)
X_scaled = X_scaled.reshape(X.shape)  # (1212, 30, 13)

# y scaling (for regression)
y_scaler = MinMaxScaler()
y_scaler.fit(y)  # fit only once
y_scaled = y_scaler.transform(y)  # transform separately

# %%
split_index = int(len(X_scaled) * 0.8)

# Training set: the first 80% of the sequence
X_train = X_scaled[:split_index]
y_train = y_scaled[:split_index]

# Validation set: the most recent 20%
X_val = X_scaled[split_index:]
y_val = y_scaled[split_index:]

print("X_train shape:", X_train.shape)
print("X_val shape:", X_val.shape)
# Out:
# X_train shape: (969, 30, 13)
# X_val shape: (243, 30, 13)

# %%
# Set input dimensions
timesteps = X_train.shape[1]  # ➜ 30 (N-day input window)
features = X_train.shape[2]   # ➜ 13 (number of input features per time step)

# Build Stacked GRU model
stacked_gru_model = Sequential([
    GRU(64, return_sequences=True, input_shape=(timesteps, features)),  # First GRU layer returns full sequence
    GRU(32),  # Second GRU layer processes the sequence summary
    Dropout(0.2),
    Dense(1)
])

# Compile
stacked_gru_model.compile(
    optimizer=Adam(learning_rate=0.001),
    loss='mse',
    metrics=['mae']
)

# Summary
stacked_gru_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru_1 (GRU)                 (None, 30, 64)            15168
#
#  gru_2 (GRU)                 (None, 32)                9408
#
#  dropout_1 (Dropout)         (None, 32)                0
#
#  dense_2 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 24609 (96.13 KB)
# Trainable params: 24609 (96.13 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Train
history = stacked_gru_model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=50,
    batch_size=32,
    verbose=1
)
# Out:
# Epoch 1/50
# 31/31 [==============================] - 8s 51ms/step - loss: 0.0204 - mae: 0.1080 - val_loss: 0.0306 - val_mae: 0.1650
# Epoch 2/50
# 31/31 [==============================] - 0s 16ms/step - loss: 0.0042 - mae: 0.0509 - val_loss: 0.0085 - val_mae: 0.0818
# Epoch 3/50
# 31/31 [==============================] - 0s 16ms/step - loss: 0.0025 - mae: 0.0392 - val_loss: 0.0058 - val_mae: 0.0662
# Epoch 4/50
# 31/31 [==============================] - 0s 16ms/step - loss: 0.0022 - mae: 0.0374 - val_loss: 0.0036 - val_mae: 0.0498
# Epoch 5/50
# 31/31 [==============================] - 0s 16ms/step - loss: 0.0021 - mae: 0.0356 - val_loss: 0.0043 - val_mae: 0.0557
# Epoch 6/50
# 31/31 [==============================] - 0s 16ms/step - loss: 0.0020 - mae: 0.0346 - val_loss: 0.0076 - val_mae: 0.0782
# Epoch 7/50
# 31/31 [==============================] - 0s 16ms/step - loss: 0.0018 - mae: 0.0337 - val_loss: 0.0061 - val_mae: 0.0683
# Epoch 8/50
# 31/31 [==============================] - 0s 16ms/step - loss: 0.0019 - mae: 0.0343 - val_loss: 0.0033 - val_mae: 0.0477
# Epoch 9/50
# 31/31 [==============================] - 1s 17ms/step - loss: 0.0017 - mae: 0.0316 - val_loss: 0.0034 - val_mae: 0.0484
# Epoch 10/50
# 31/31 [==============================] - 0s 16ms/step - loss: 0.0019 - mae: 0.0346 - val_loss: 0.0018 - val_mae: 0.0335
# Epoch 11/50
# 31/31 [==============================] - 1s 16ms/step - loss: 0.0019 - mae: 0.0343 - val_loss: 0.0031 - val_mae: 0.0458
# Epoch 12/50
# 31/31 [==============================] - 0s 16ms/step - loss: 0.0018 - mae: 0.0333 - val_loss: 0.0063 - val_mae: 0.0706
# Epoch 13/50
# 31/31 [==============================] - 0s 16ms/step - loss: 0.0017 - mae: 0.0322 - val_loss: 0.0018 - val_mae: 0.0336
# Epoch 14/50
# 31/31 [==============================] - 0s 16ms/step - loss: 0.0018 - mae: 0.0326 - val_loss: 0.0066 - val_mae: 0.0733
# Epoch 15/50
# 31/31 [==============================] - 0s 16ms/step - loss: 0.0017 - mae: 0.0327 - val_loss: 0.0059 - val_mae: 0.0684
# Epoch 16/50
# 31/31 [==============================] - 1s 17ms/step - loss: 0.0019 - mae: 0.0335 - val_loss: 0.0028 - val_mae: 0.0441
# Epoch 17/50
# 31/31 [==============================] - 1s 17ms/step - loss: 0.0014 - mae: 0.0295 - val_loss: 0.0021 - val_mae: 0.0375
# Epoch 18/50
# 31/31 [==============================] - 0s 16ms/step - loss: 0.0015 - mae: 0.0305 - val_loss: 0.0025 - val_mae: 0.0417
# Epoch 19/50
# 31/31 [==============================] - 0s 16ms/step - loss: 0.0014 - mae: 0.0295 - val_loss: 0.0047 - val_mae: 0.0608
# Epoch 20/50
# 31/31 [==============================] - 1s 16ms/step - loss: 0.0016 - mae: 0.0310 - val_loss: 0.0046 - val_mae: 0.0593
# Epoch 21/50
# 31/31 [==============================] - 0s 16ms/step - loss: 0.0016 - mae: 0.0302 - val_loss: 0.0044 - val_mae: 0.0571
# Epoch 22/50
# 31/31 [==============================] - 0s 16ms/step - loss: 0.0015 - mae: 0.0299 - val_loss: 0.0043 - val_mae: 0.0574
# Epoch 23/50
# 31/31 [==============================] - 1s 17ms/step - loss: 0.0014 - mae: 0.0293 - val_loss: 0.0040 - val_mae: 0.0547
# Epoch 24/50
# 31/31 [==============================] - 0s 16ms/step - loss: 0.0013 - mae: 0.0280 - val_loss: 0.0041 - val_mae: 0.0557
# Epoch 25/50
# 31/31 [==============================] - 0s 16ms/step - loss: 0.0016 - mae: 0.0317 - val_loss: 0.0018 - val_mae: 0.0331
# Epoch 26/50
# 31/31 [==============================] - 1s 17ms/step - loss: 0.0014 - mae: 0.0300 - val_loss: 0.0035 - val_mae: 0.0507
# Epoch 27/50
# 31/31 [==============================] - 1s 18ms/step - loss: 0.0014 - mae: 0.0285 - val_loss: 0.0072 - val_mae: 0.0768
# Epoch 28/50
# 31/31 [==============================] - 1s 18ms/step - loss: 0.0016 - mae: 0.0316 - val_loss: 0.0070 - val_mae: 0.0761
# Epoch 29/50
# 31/31 [==============================] - 1s 23ms/step - loss: 0.0015 - mae: 0.0295 - val_loss: 0.0037 - val_mae: 0.0525
# Epoch 30/50
# 31/31 [==============================] - 1s 21ms/step - loss: 0.0012 - mae: 0.0273 - val_loss: 0.0033 - val_mae: 0.0489
# Epoch 31/50
# 31/31 [==============================] - 1s 16ms/step - loss: 0.0014 - mae: 0.0286 - val_loss: 0.0038 - val_mae: 0.0531
# Epoch 32/50
# 31/31 [==============================] - 1s 17ms/step - loss: 0.0011 - mae: 0.0259 - val_loss: 0.0021 - val_mae: 0.0376
# Epoch 33/50
# 31/31 [==============================] - 1s 16ms/step - loss: 0.0012 - mae: 0.0265 - val_loss: 0.0044 - val_mae: 0.0580
# Epoch 34/50
# 31/31 [==============================] - 1s 17ms/step - loss: 0.0013 - mae: 0.0281 - val_loss: 0.0021 - val_mae: 0.0376
# Epoch 35/50
# 31/31 [==============================] - 1s 16ms/step - loss: 0.0012 - mae: 0.0263 - val_loss: 0.0014 - val_mae: 0.0293
# Epoch 36/50
# 31/31 [==============================] - 1s 17ms/step - loss: 0.0012 - mae: 0.0276 - val_loss: 0.0024 - val_mae: 0.0405
# Epoch 37/50
# 31/31 [==============================] - 1s 17ms/step - loss: 0.0012 - mae: 0.0264 - val_loss: 0.0022 - val_mae: 0.0388
# Epoch 38/50
# 31/31 [==============================] - 1s 17ms/step - loss: 0.0011 - mae: 0.0254 - val_loss: 0.0016 - val_mae: 0.0312
# Epoch 39/50
# 31/31 [==============================] - 1s 17ms/step - loss: 0.0013 - mae: 0.0279 - val_loss: 0.0039 - val_mae: 0.0542
# Epoch 40/50
# 31/31 [==============================] - 1s 17ms/step - loss: 0.0011 - mae: 0.0260 - val_loss: 0.0046 - val_mae: 0.0589
# Epoch 41/50
# 31/31 [==============================] - 1s 17ms/step - loss: 0.0011 - mae: 0.0255 - val_loss: 0.0022 - val_mae: 0.0378
# Epoch 42/50
# 31/31 [==============================] - 1s 17ms/step - loss: 9.3349e-04 - mae: 0.0238 - val_loss: 0.0022 - val_mae: 0.0389
# Epoch 43/50
# 31/31 [==============================] - 1s 18ms/step - loss: 0.0010 - mae: 0.0249 - val_loss: 0.0046 - val_mae: 0.0591
# Epoch 44/50
# 31/31 [==============================] - 1s 18ms/step - loss: 0.0010 - mae: 0.0252 - val_loss: 0.0037 - val_mae: 0.0526
# Epoch 45/50
# 31/31 [==============================] - 1s 17ms/step - loss: 0.0010 - mae: 0.0250 - val_loss: 0.0039 - val_mae: 0.0535
# Epoch 46/50
# 31/31 [==============================] - 1s 17ms/step - loss: 0.0011 - mae: 0.0254 - val_loss: 0.0023 - val_mae: 0.0394
# Epoch 47/50
# 31/31 [==============================] - 1s 17ms/step - loss: 0.0011 - mae: 0.0263 - val_loss: 0.0045 - val_mae: 0.0592
# Epoch 48/50
# 31/31 [==============================] - 1s 17ms/step - loss: 9.5323e-04 - mae: 0.0235 - val_loss: 0.0053 - val_mae: 0.0647
# Epoch 49/50
# 31/31 [==============================] - 1s 17ms/step - loss: 0.0010 - mae: 0.0246 - val_loss: 0.0042 - val_mae: 0.0556
# Epoch 50/50
# 31/31 [==============================] - 1s 18ms/step - loss: 9.8406e-04 - mae: 0.0240 - val_loss: 0.0034 - val_mae: 0.0496

# %%
# Predict
y_pred = stacked_gru_model.predict(X_val)

# Inverse transform
y_pred = y_scaler.inverse_transform(y_pred)
y_val = y_scaler.inverse_transform(y_val)

index = stock_df.index[-len(y_val):]
# Out:
# 8/8 [==============================] - 1s 5ms/step

# %%
# Visualise
plt.figure(figsize=(12, 5))
plt.plot(index, y_val, label='True')
plt.plot(index, y_pred, label='Predicted (Stacked GRU)', linestyle='--')
plt.title('Stacked GRU Forecast vs True')
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.legend()
plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error, r2_score

stacked_gru_rmse = np.sqrt(mean_squared_error(y_val, y_pred))
stacked_gru_mae = mean_absolute_error(y_val, y_pred)
stacked_gru_mape = mean_absolute_percentage_error(y_val, y_pred)
stacked_gru_r2 = r2_score(y_val, y_pred)

print("📊 Stacked GRU Performance:")
print(f"RMSE: {stacked_gru_rmse:.4f}")
print(f"MAE: {stacked_gru_mae:.4f}")
print(f"MAPE: {stacked_gru_mape:.4%}")
print(f"R² Score: {stacked_gru_r2:.4f}")
# Out:
# 📊 Stacked GRU Performance:
# RMSE: 6.6323
# MAE: 5.6433
# MAPE: 4.2476%
# R² Score: 0.8070

# %% [markdown]
# - **RMSE**: `8.07` → Lower error compared to the single-layer GRU.
# - **MAE**: `7.08` → Absolute error is reduced by about 3 points.
# - **MAPE**: `5.36%` → Improved forecasting accuracy.
# - **R² Score**: `0.7143` → Explains approximately **71%** of the variance in the targ
#
# The stacked GRU significantly outperforms the basic GRU across all metrics.
# Thanks to its deeper structure, it can **learn more complex temporal patterns**, making it more reliable for time-series forecasting.et.

# %%
# Feature scaling 
X_scaler = MinMaxScaler()
X_scaled = X_scaler.fit_transform(X_reshaped)
X_scaled = X_scaled.reshape(X.shape)  # (1212, 30, 13)

# y scaling (for regression)
y_scaler = MinMaxScaler()
y_scaler.fit(y)  # fit only once
y_scaled = y_scaler.transform(y)  # transform separately

# %%
split_index = int(len(X_scaled) * 0.8)

# Training set: the first 80% of the sequence
X_train = X_scaled[:split_index]
y_train = y_scaled[:split_index]

# Validation set: the most recent 20%
X_val = X_scaled[split_index:]
y_val = y_scaled[split_index:]

print("X_train shape:", X_train.shape)
print("X_val shape:", X_val.shape)
# Out:
# X_train shape: (969, 30, 13)
# X_val shape: (243, 30, 13)

# %%
# Set input dimensions
timesteps = X_train.shape[1]  # ➜ 30 (N-day input window)
features = X_train.shape[2]   # ➜ 13 (number of input features per time step)

deep_gru_model = Sequential([
    GRU(128, return_sequences=True, input_shape=(timesteps, features)),
    Dropout(0.2),
    GRU(64, return_sequences=True),
    Dropout(0.2),
    GRU(32), 
    Dense(1)
])

deep_gru_model.compile(optimizer='adam', loss='mse', metrics=['mae'])
deep_gru_model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru_6 (GRU)                 (None, 30, 128)           54912
#
#  dropout_4 (Dropout)         (None, 30, 128)           0
#
#  gru_7 (GRU)                 (None, 30, 64)            37248
#
#  dropout_5 (Dropout)         (None, 30, 64)            0
#
#  gru_8 (GRU)                 (None, 32)                9408
#
#  dense_4 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 101601 (396.88 KB)
# Trainable params: 101601 (396.88 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Train the model
deep_gru_history = deep_gru_model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=50,
    batch_size=32,
    verbose=1
)
# Out:
# Epoch 1/50
# 31/31 [==============================] - 1s 37ms/step - loss: 6.1425e-04 - mae: 0.0191 - val_loss: 0.0175 - val_mae: 0.1064
# Epoch 2/50
# 31/31 [==============================] - 1s 27ms/step - loss: 5.6283e-04 - mae: 0.0184 - val_loss: 0.0190 - val_mae: 0.1115
# Epoch 3/50
# 31/31 [==============================] - 1s 28ms/step - loss: 5.6541e-04 - mae: 0.0181 - val_loss: 0.0213 - val_mae: 0.1232
# Epoch 4/50
# 31/31 [==============================] - 1s 29ms/step - loss: 5.4826e-04 - mae: 0.0184 - val_loss: 0.0185 - val_mae: 0.1108
# Epoch 5/50
# 31/31 [==============================] - 1s 29ms/step - loss: 5.8426e-04 - mae: 0.0189 - val_loss: 0.0160 - val_mae: 0.1008
# Epoch 6/50
# 31/31 [==============================] - 1s 33ms/step - loss: 5.4812e-04 - mae: 0.0183 - val_loss: 0.0202 - val_mae: 0.1199
# Epoch 7/50
# 31/31 [==============================] - 1s 49ms/step - loss: 5.3474e-04 - mae: 0.0182 - val_loss: 0.0187 - val_mae: 0.1148
# Epoch 8/50
# 31/31 [==============================] - 2s 52ms/step - loss: 5.6305e-04 - mae: 0.0184 - val_loss: 0.0207 - val_mae: 0.1232
# Epoch 9/50
# 31/31 [==============================] - 1s 43ms/step - loss: 6.4104e-04 - mae: 0.0199 - val_loss: 0.0193 - val_mae: 0.1170
# Epoch 10/50
# 31/31 [==============================] - 1s 47ms/step - loss: 6.0673e-04 - mae: 0.0192 - val_loss: 0.0150 - val_mae: 0.0998
# Epoch 11/50
# 31/31 [==============================] - 1s 41ms/step - loss: 5.2563e-04 - mae: 0.0179 - val_loss: 0.0163 - val_mae: 0.1037
# Epoch 12/50
# 31/31 [==============================] - 1s 41ms/step - loss: 5.4931e-04 - mae: 0.0185 - val_loss: 0.0209 - val_mae: 0.1243
# Epoch 13/50
# 31/31 [==============================] - 2s 52ms/step - loss: 5.4444e-04 - mae: 0.0182 - val_loss: 0.0238 - val_mae: 0.1328
# Epoch 14/50
# 31/31 [==============================] - 2s 55ms/step - loss: 5.2032e-04 - mae: 0.0176 - val_loss: 0.0216 - val_mae: 0.1254
# Epoch 15/50
# 31/31 [==============================] - 1s 49ms/step - loss: 5.6260e-04 - mae: 0.0185 - val_loss: 0.0176 - val_mae: 0.1108
# Epoch 16/50
# 31/31 [==============================] - 1s 43ms/step - loss: 6.0094e-04 - mae: 0.0191 - val_loss: 0.0131 - val_mae: 0.0907
# Epoch 17/50
# 31/31 [==============================] - 1s 43ms/step - loss: 4.9615e-04 - mae: 0.0172 - val_loss: 0.0171 - val_mae: 0.1097
# Epoch 18/50
# 31/31 [==============================] - 1s 48ms/step - loss: 4.9464e-04 - mae: 0.0170 - val_loss: 0.0152 - val_mae: 0.1005
# Epoch 19/50
# 31/31 [==============================] - 1s 43ms/step - loss: 5.2988e-04 - mae: 0.0178 - val_loss: 0.0136 - val_mae: 0.0905
# Epoch 20/50
# 31/31 [==============================] - 2s 50ms/step - loss: 6.1728e-04 - mae: 0.0192 - val_loss: 0.0247 - val_mae: 0.1336
# Epoch 21/50
# 31/31 [==============================] - 1s 47ms/step - loss: 5.8640e-04 - mae: 0.0191 - val_loss: 0.0157 - val_mae: 0.1031
# Epoch 22/50
# 31/31 [==============================] - 1s 41ms/step - loss: 5.1800e-04 - mae: 0.0176 - val_loss: 0.0199 - val_mae: 0.1216
# Epoch 23/50
# 31/31 [==============================] - 1s 47ms/step - loss: 5.3917e-04 - mae: 0.0180 - val_loss: 0.0216 - val_mae: 0.1231
# Epoch 24/50
# 31/31 [==============================] - 2s 51ms/step - loss: 4.8357e-04 - mae: 0.0173 - val_loss: 0.0178 - val_mae: 0.1105
# Epoch 25/50
# 31/31 [==============================] - 2s 60ms/step - loss: 5.3360e-04 - mae: 0.0179 - val_loss: 0.0176 - val_mae: 0.1077
# Epoch 26/50
# 31/31 [==============================] - 2s 54ms/step - loss: 5.2887e-04 - mae: 0.0180 - val_loss: 0.0180 - val_mae: 0.1106
# Epoch 27/50
# 31/31 [==============================] - 1s 43ms/step - loss: 5.1580e-04 - mae: 0.0177 - val_loss: 0.0197 - val_mae: 0.1160
# Epoch 28/50
# 31/31 [==============================] - 1s 47ms/step - loss: 4.5771e-04 - mae: 0.0167 - val_loss: 0.0158 - val_mae: 0.1008
# Epoch 29/50
# 31/31 [==============================] - 1s 47ms/step - loss: 6.4499e-04 - mae: 0.0197 - val_loss: 0.0155 - val_mae: 0.1038
# Epoch 30/50
# 31/31 [==============================] - 1s 47ms/step - loss: 4.8921e-04 - mae: 0.0170 - val_loss: 0.0178 - val_mae: 0.1101
# Epoch 31/50
# 31/31 [==============================] - 2s 52ms/step - loss: 4.7348e-04 - mae: 0.0170 - val_loss: 0.0206 - val_mae: 0.1216
# Epoch 32/50
# 31/31 [==============================] - 1s 44ms/step - loss: 4.8168e-04 - mae: 0.0170 - val_loss: 0.0222 - val_mae: 0.1307
# Epoch 33/50
# 31/31 [==============================] - 2s 49ms/step - loss: 4.9447e-04 - mae: 0.0174 - val_loss: 0.0192 - val_mae: 0.1146
# Epoch 34/50
# 31/31 [==============================] - 2s 56ms/step - loss: 4.6977e-04 - mae: 0.0167 - val_loss: 0.0176 - val_mae: 0.1073
# Epoch 35/50
# 31/31 [==============================] - 2s 67ms/step - loss: 4.7257e-04 - mae: 0.0168 - val_loss: 0.0201 - val_mae: 0.1198
# Epoch 36/50
# 31/31 [==============================] - 2s 73ms/step - loss: 4.6704e-04 - mae: 0.0164 - val_loss: 0.0202 - val_mae: 0.1193
# Epoch 37/50
# 31/31 [==============================] - 2s 50ms/step - loss: 4.6512e-04 - mae: 0.0169 - val_loss: 0.0137 - val_mae: 0.0927
# Epoch 38/50
# 31/31 [==============================] - 2s 60ms/step - loss: 5.7030e-04 - mae: 0.0186 - val_loss: 0.0123 - val_mae: 0.0855
# Epoch 39/50
# 31/31 [==============================] - 2s 50ms/step - loss: 6.1900e-04 - mae: 0.0200 - val_loss: 0.0142 - val_mae: 0.0954
# Epoch 40/50
# 31/31 [==============================] - 2s 58ms/step - loss: 4.6636e-04 - mae: 0.0172 - val_loss: 0.0195 - val_mae: 0.1193
# Epoch 41/50
# 31/31 [==============================] - 2s 50ms/step - loss: 4.6461e-04 - mae: 0.0169 - val_loss: 0.0213 - val_mae: 0.1224
# Epoch 42/50
# 31/31 [==============================] - 2s 57ms/step - loss: 4.8407e-04 - mae: 0.0171 - val_loss: 0.0178 - val_mae: 0.1068
# Epoch 43/50
# 31/31 [==============================] - 2s 67ms/step - loss: 5.2755e-04 - mae: 0.0179 - val_loss: 0.0161 - val_mae: 0.0995
# Epoch 44/50
# 31/31 [==============================] - 2s 73ms/step - loss: 4.5966e-04 - mae: 0.0166 - val_loss: 0.0182 - val_mae: 0.1098
# Epoch 45/50
# 31/31 [==============================] - 3s 88ms/step - loss: 4.2739e-04 - mae: 0.0158 - val_loss: 0.0194 - val_mae: 0.1176
# Epoch 46/50
# 31/31 [==============================] - 2s 78ms/step - loss: 4.1398e-04 - mae: 0.0158 - val_loss: 0.0236 - val_mae: 0.1291
# Epoch 47/50
# 31/31 [==============================] - 2s 76ms/step - loss: 4.1696e-04 - mae: 0.0156 - val_loss: 0.0164 - val_mae: 0.1051
# Epoch 48/50
# 31/31 [==============================] - 2s 71ms/step - loss: 4.3542e-04 - mae: 0.0162 - val_loss: 0.0198 - val_mae: 0.1154
# Epoch 49/50
# 31/31 [==============================] - 2s 65ms/step - loss: 5.5895e-04 - mae: 0.0185 - val_loss: 0.0240 - val_mae: 0.1319
# Epoch 50/50
# 31/31 [==============================] - 2s 67ms/step - loss: 4.7368e-04 - mae: 0.0170 - val_loss: 0.0166 - val_mae: 0.1046

# %%
# Predict and inverse scale
y_pred = deep_gru_model.predict(X_val)
y_pred = y_scaler.inverse_transform(y_pred)
y_val = y_scaler.inverse_transform(y_val)

index = stock_df.index[-len(y_val):]
# Out:
# 8/8 [==============================] - 0s 8ms/step

# %%
# Plotting
plt.figure(figsize=(12, 5))
plt.plot(index, y_val, label='True')
plt.plot(index, y_pred, label='Predicted (Deep GRU)')
plt.title('Deep GRU Forecast vs True')
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.legend()
plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error, r2_score

deep_gru_rmse = np.sqrt(mean_squared_error(y_val, y_pred))
deep_gru_mae = mean_absolute_error(y_val, y_pred)
deep_gru_mape = mean_absolute_percentage_error(y_val, y_pred)
deep_gru_r2 = r2_score(y_val, y_pred)

print("📊 Deep GRU Performance:")
print(f"RMSE: {deep_gru_rmse:.4f}")
print(f"MAE: {deep_gru_mae:.4f}")
print(f"MAPE: {deep_gru_mape:.4%}")
print(f"R² Score: {deep_gru_r2:.4f}")
# Out:
# 📊 Deep GRU Performance:
# RMSE: 14.6813
# MAE: 11.9051
# MAPE: 8.7186%
# R² Score: 0.0545

# %%
# Feature scaling 
X_scaler = MinMaxScaler()
X_scaled = X_scaler.fit_transform(X_reshaped)
X_scaled = X_scaled.reshape(X.shape)  # (1212, 30, 13)

# y scaling (for regression)
y_scaler = MinMaxScaler()
y_scaler.fit(y)  # fit only once
y_scaled = y_scaler.transform(y)  # transform separately

# %%
split_index = int(len(X_scaled) * 0.8)

# Training set: the first 80% of the sequence
X_train = X_scaled[:split_index]
y_train = y_scaled[:split_index]

# Validation set: the most recent 20%
X_val = X_scaled[split_index:]
y_val = y_scaled[split_index:]

print("X_train shape:", X_train.shape)
print("X_val shape:", X_val.shape)
# Out:
# X_train shape: (969, 30, 13)
# X_val shape: (243, 30, 13)

# %%
# Set input dimensions
timesteps = X_train.shape[1]  # ➜ 30 (N-day input window)
features = X_train.shape[2]   # ➜ 13 (number of input features per time step)

# Define the improved Stacked GRU model
improved_gru_model = Sequential([
    GRU(64, return_sequences=True, input_shape=(timesteps, features)),
    GRU(32),
    Dropout(0.2),
    Dense(32, activation='relu'),
    Dense(1)
])

# Compile the model
improved_gru_model.compile(
    optimizer=Adam(learning_rate=0.0005),
    loss='mse',
    metrics=['mae']
)

improved_gru_model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru_9 (GRU)                 (None, 30, 64)            15168
#
#  gru_10 (GRU)                (None, 32)                9408
#
#  dropout_6 (Dropout)         (None, 32)                0
#
#  dense_5 (Dense)             (None, 32)                1056
#
#  dense_6 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 25665 (100.25 KB)
# Trainable params: 25665 (100.25 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Train the model
history = improved_gru_model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=100,
    batch_size=32,
    verbose=1
)
# Out:
# Epoch 1/100
# 31/31 [==============================] - 9s 55ms/step - loss: 0.0245 - mae: 0.1167 - val_loss: 0.0217 - val_mae: 0.1314
# Epoch 2/100
# 31/31 [==============================] - 0s 16ms/step - loss: 0.0049 - mae: 0.0547 - val_loss: 0.0103 - val_mae: 0.0885
# Epoch 3/100
# 31/31 [==============================] - 0s 16ms/step - loss: 0.0028 - mae: 0.0413 - val_loss: 0.0071 - val_mae: 0.0705
# Epoch 4/100
# 31/31 [==============================] - 0s 16ms/step - loss: 0.0030 - mae: 0.0424 - val_loss: 0.0061 - val_mae: 0.0642
# Epoch 5/100
# 31/31 [==============================] - 0s 16ms/step - loss: 0.0026 - mae: 0.0405 - val_loss: 0.0083 - val_mae: 0.0782
# Epoch 6/100
# 31/31 [==============================] - 0s 16ms/step - loss: 0.0025 - mae: 0.0382 - val_loss: 0.0062 - val_mae: 0.0666
# Epoch 7/100
# 31/31 [==============================] - 1s 17ms/step - loss: 0.0023 - mae: 0.0373 - val_loss: 0.0052 - val_mae: 0.0601
# Epoch 8/100
# 31/31 [==============================] - 1s 23ms/step - loss: 0.0024 - mae: 0.0383 - val_loss: 0.0098 - val_mae: 0.0894
# Epoch 9/100
# 31/31 [==============================] - 1s 19ms/step - loss: 0.0021 - mae: 0.0348 - val_loss: 0.0062 - val_mae: 0.0682
# Epoch 10/100
# 31/31 [==============================] - 1s 18ms/step - loss: 0.0016 - mae: 0.0316 - val_loss: 0.0066 - val_mae: 0.0710
# Epoch 11/100
# 31/31 [==============================] - 1s 18ms/step - loss: 0.0016 - mae: 0.0319 - val_loss: 0.0052 - val_mae: 0.0614
# Epoch 12/100
# 31/31 [==============================] - 1s 19ms/step - loss: 0.0016 - mae: 0.0306 - val_loss: 0.0056 - val_mae: 0.0644
# Epoch 13/100
# 31/31 [==============================] - 1s 17ms/step - loss: 0.0016 - mae: 0.0308 - val_loss: 0.0080 - val_mae: 0.0806
# Epoch 14/100
# 31/31 [==============================] - 1s 17ms/step - loss: 0.0014 - mae: 0.0289 - val_loss: 0.0036 - val_mae: 0.0502
# Epoch 15/100
# 31/31 [==============================] - 1s 21ms/step - loss: 0.0015 - mae: 0.0300 - val_loss: 0.0061 - val_mae: 0.0685
# Epoch 16/100
# 31/31 [==============================] - 1s 20ms/step - loss: 0.0016 - mae: 0.0308 - val_loss: 0.0056 - val_mae: 0.0651
# Epoch 17/100
# 31/31 [==============================] - 1s 21ms/step - loss: 0.0015 - mae: 0.0304 - val_loss: 0.0065 - val_mae: 0.0716
# Epoch 18/100
# 31/31 [==============================] - 1s 19ms/step - loss: 0.0012 - mae: 0.0271 - val_loss: 0.0074 - val_mae: 0.0768
# Epoch 19/100
# 31/31 [==============================] - 1s 19ms/step - loss: 0.0013 - mae: 0.0279 - val_loss: 0.0087 - val_mae: 0.0841
# Epoch 20/100
# 31/31 [==============================] - 1s 18ms/step - loss: 0.0012 - mae: 0.0273 - val_loss: 0.0054 - val_mae: 0.0639
# Epoch 21/100
# 31/31 [==============================] - 1s 18ms/step - loss: 0.0013 - mae: 0.0278 - val_loss: 0.0070 - val_mae: 0.0746
# Epoch 22/100
# 31/31 [==============================] - 1s 19ms/step - loss: 0.0013 - mae: 0.0278 - val_loss: 0.0074 - val_mae: 0.0767
# Epoch 23/100
# 31/31 [==============================] - 1s 17ms/step - loss: 0.0012 - mae: 0.0270 - val_loss: 0.0072 - val_mae: 0.0762
# Epoch 24/100
# 31/31 [==============================] - 1s 17ms/step - loss: 0.0012 - mae: 0.0264 - val_loss: 0.0066 - val_mae: 0.0718
# Epoch 25/100
# 31/31 [==============================] - 1s 17ms/step - loss: 0.0011 - mae: 0.0258 - val_loss: 0.0065 - val_mae: 0.0719
# Epoch 26/100
# 31/31 [==============================] - 1s 17ms/step - loss: 0.0012 - mae: 0.0273 - val_loss: 0.0074 - val_mae: 0.0772
# Epoch 27/100
# 31/31 [==============================] - 1s 17ms/step - loss: 9.8398e-04 - mae: 0.0243 - val_loss: 0.0054 - val_mae: 0.0640
# Epoch 28/100
# 31/31 [==============================] - 1s 19ms/step - loss: 9.9250e-04 - mae: 0.0243 - val_loss: 0.0062 - val_mae: 0.0697
# Epoch 29/100
# 31/31 [==============================] - 1s 19ms/step - loss: 0.0011 - mae: 0.0251 - val_loss: 0.0075 - val_mae: 0.0781
# Epoch 30/100
# 31/31 [==============================] - 1s 17ms/step - loss: 9.6869e-04 - mae: 0.0242 - val_loss: 0.0094 - val_mae: 0.0884
# Epoch 31/100
# 31/31 [==============================] - 1s 17ms/step - loss: 0.0010 - mae: 0.0255 - val_loss: 0.0082 - val_mae: 0.0822
# Epoch 32/100
# 31/31 [==============================] - 1s 18ms/step - loss: 9.7646e-04 - mae: 0.0243 - val_loss: 0.0087 - val_mae: 0.0846
# Epoch 33/100
# 31/31 [==============================] - 1s 17ms/step - loss: 9.3435e-04 - mae: 0.0237 - val_loss: 0.0089 - val_mae: 0.0858
# Epoch 34/100
# 31/31 [==============================] - 1s 17ms/step - loss: 9.2071e-04 - mae: 0.0238 - val_loss: 0.0110 - val_mae: 0.0971
# Epoch 35/100
# 31/31 [==============================] - 1s 20ms/step - loss: 9.8536e-04 - mae: 0.0243 - val_loss: 0.0047 - val_mae: 0.0595
# Epoch 36/100
# 31/31 [==============================] - 1s 18ms/step - loss: 8.4148e-04 - mae: 0.0226 - val_loss: 0.0070 - val_mae: 0.0743
# Epoch 37/100
# 31/31 [==============================] - 1s 18ms/step - loss: 8.3341e-04 - mae: 0.0227 - val_loss: 0.0096 - val_mae: 0.0900
# Epoch 38/100
# 31/31 [==============================] - 1s 18ms/step - loss: 9.1976e-04 - mae: 0.0237 - val_loss: 0.0065 - val_mae: 0.0717
# Epoch 39/100
# 31/31 [==============================] - 1s 18ms/step - loss: 7.9374e-04 - mae: 0.0220 - val_loss: 0.0051 - val_mae: 0.0616
# Epoch 40/100
# 31/31 [==============================] - 1s 18ms/step - loss: 8.5680e-04 - mae: 0.0226 - val_loss: 0.0067 - val_mae: 0.0727
# Epoch 41/100
# 31/31 [==============================] - 1s 18ms/step - loss: 7.9372e-04 - mae: 0.0222 - val_loss: 0.0082 - val_mae: 0.0822
# Epoch 42/100
# 31/31 [==============================] - 1s 20ms/step - loss: 0.0010 - mae: 0.0245 - val_loss: 0.0058 - val_mae: 0.0673
# Epoch 43/100
# 31/31 [==============================] - 1s 20ms/step - loss: 8.1321e-04 - mae: 0.0219 - val_loss: 0.0080 - val_mae: 0.0808
# Epoch 44/100
# 31/31 [==============================] - 1s 20ms/step - loss: 8.4934e-04 - mae: 0.0228 - val_loss: 0.0093 - val_mae: 0.0885
# Epoch 45/100
# 31/31 [==============================] - 1s 20ms/step - loss: 8.4475e-04 - mae: 0.0221 - val_loss: 0.0087 - val_mae: 0.0845
# Epoch 46/100
# 31/31 [==============================] - 1s 21ms/step - loss: 7.9700e-04 - mae: 0.0218 - val_loss: 0.0064 - val_mae: 0.0711
# Epoch 47/100
# 31/31 [==============================] - 1s 22ms/step - loss: 7.4351e-04 - mae: 0.0212 - val_loss: 0.0064 - val_mae: 0.0709
# Epoch 48/100
# 31/31 [==============================] - 1s 24ms/step - loss: 8.1225e-04 - mae: 0.0220 - val_loss: 0.0084 - val_mae: 0.0832
# Epoch 49/100
# 31/31 [==============================] - 1s 22ms/step - loss: 7.7871e-04 - mae: 0.0218 - val_loss: 0.0078 - val_mae: 0.0795
# Epoch 50/100
# 31/31 [==============================] - 1s 21ms/step - loss: 7.1912e-04 - mae: 0.0208 - val_loss: 0.0075 - val_mae: 0.0777
# Epoch 51/100
# 31/31 [==============================] - 1s 19ms/step - loss: 7.7010e-04 - mae: 0.0217 - val_loss: 0.0082 - val_mae: 0.0815
# Epoch 52/100
# 31/31 [==============================] - 1s 18ms/step - loss: 7.5740e-04 - mae: 0.0213 - val_loss: 0.0104 - val_mae: 0.0937
# Epoch 53/100
# 31/31 [==============================] - 1s 19ms/step - loss: 7.3532e-04 - mae: 0.0207 - val_loss: 0.0131 - val_mae: 0.1068
# Epoch 54/100
# 31/31 [==============================] - 1s 22ms/step - loss: 8.2093e-04 - mae: 0.0224 - val_loss: 0.0138 - val_mae: 0.1096
# Epoch 55/100
# 31/31 [==============================] - 1s 19ms/step - loss: 7.7121e-04 - mae: 0.0216 - val_loss: 0.0144 - val_mae: 0.1121
# Epoch 56/100
# 31/31 [==============================] - 1s 18ms/step - loss: 7.7915e-04 - mae: 0.0210 - val_loss: 0.0092 - val_mae: 0.0873
# Epoch 57/100
# 31/31 [==============================] - 1s 18ms/step - loss: 6.4444e-04 - mae: 0.0199 - val_loss: 0.0104 - val_mae: 0.0930
# Epoch 58/100
# 31/31 [==============================] - 1s 18ms/step - loss: 6.7625e-04 - mae: 0.0201 - val_loss: 0.0091 - val_mae: 0.0866
# Epoch 59/100
# 31/31 [==============================] - 1s 19ms/step - loss: 6.4460e-04 - mae: 0.0194 - val_loss: 0.0086 - val_mae: 0.0838
# Epoch 60/100
# 31/31 [==============================] - 1s 20ms/step - loss: 7.2943e-04 - mae: 0.0209 - val_loss: 0.0112 - val_mae: 0.0975
# Epoch 61/100
# 31/31 [==============================] - 1s 20ms/step - loss: 6.8704e-04 - mae: 0.0205 - val_loss: 0.0128 - val_mae: 0.1045
# Epoch 62/100
# 31/31 [==============================] - 1s 19ms/step - loss: 7.0458e-04 - mae: 0.0199 - val_loss: 0.0115 - val_mae: 0.0979
# Epoch 63/100
# 31/31 [==============================] - 1s 18ms/step - loss: 7.1970e-04 - mae: 0.0206 - val_loss: 0.0114 - val_mae: 0.0975
# Epoch 64/100
# 31/31 [==============================] - 1s 18ms/step - loss: 6.5710e-04 - mae: 0.0196 - val_loss: 0.0096 - val_mae: 0.0881
# Epoch 65/100
# 31/31 [==============================] - 1s 18ms/step - loss: 6.9143e-04 - mae: 0.0203 - val_loss: 0.0109 - val_mae: 0.0956
# Epoch 66/100
# 31/31 [==============================] - 1s 18ms/step - loss: 6.4247e-04 - mae: 0.0196 - val_loss: 0.0142 - val_mae: 0.1107
# Epoch 67/100
# 31/31 [==============================] - 1s 24ms/step - loss: 6.8123e-04 - mae: 0.0202 - val_loss: 0.0130 - val_mae: 0.1052
# Epoch 68/100
# 31/31 [==============================] - 1s 18ms/step - loss: 6.1944e-04 - mae: 0.0192 - val_loss: 0.0154 - val_mae: 0.1154
# Epoch 69/100
# 31/31 [==============================] - 1s 20ms/step - loss: 6.2343e-04 - mae: 0.0191 - val_loss: 0.0162 - val_mae: 0.1191
# Epoch 70/100
# 31/31 [==============================] - 1s 21ms/step - loss: 6.3425e-04 - mae: 0.0193 - val_loss: 0.0131 - val_mae: 0.1051
# Epoch 71/100
# 31/31 [==============================] - 1s 21ms/step - loss: 6.0963e-04 - mae: 0.0190 - val_loss: 0.0123 - val_mae: 0.1013
# Epoch 72/100
# 31/31 [==============================] - 1s 22ms/step - loss: 6.3443e-04 - mae: 0.0195 - val_loss: 0.0129 - val_mae: 0.1046
# Epoch 73/100
# 31/31 [==============================] - 1s 23ms/step - loss: 5.9670e-04 - mae: 0.0188 - val_loss: 0.0118 - val_mae: 0.0992
# Epoch 74/100
# 31/31 [==============================] - 1s 19ms/step - loss: 5.8904e-04 - mae: 0.0190 - val_loss: 0.0135 - val_mae: 0.1071
# Epoch 75/100
# 31/31 [==============================] - 1s 18ms/step - loss: 6.2972e-04 - mae: 0.0193 - val_loss: 0.0112 - val_mae: 0.0953
# Epoch 76/100
# 31/31 [==============================] - 1s 18ms/step - loss: 6.1351e-04 - mae: 0.0193 - val_loss: 0.0130 - val_mae: 0.1048
# Epoch 77/100
# 31/31 [==============================] - 1s 18ms/step - loss: 5.9475e-04 - mae: 0.0189 - val_loss: 0.0145 - val_mae: 0.1120
# Epoch 78/100
# 31/31 [==============================] - 1s 18ms/step - loss: 5.9764e-04 - mae: 0.0186 - val_loss: 0.0127 - val_mae: 0.1038
# Epoch 79/100
# 31/31 [==============================] - 1s 20ms/step - loss: 6.1078e-04 - mae: 0.0189 - val_loss: 0.0128 - val_mae: 0.1042
# Epoch 80/100
# 31/31 [==============================] - 1s 20ms/step - loss: 6.1132e-04 - mae: 0.0193 - val_loss: 0.0109 - val_mae: 0.0950
# Epoch 81/100
# 31/31 [==============================] - 1s 18ms/step - loss: 5.9745e-04 - mae: 0.0190 - val_loss: 0.0084 - val_mae: 0.0819
# Epoch 82/100
# 31/31 [==============================] - 1s 19ms/step - loss: 6.0866e-04 - mae: 0.0189 - val_loss: 0.0109 - val_mae: 0.0948
# Epoch 83/100
# 31/31 [==============================] - 1s 20ms/step - loss: 5.6387e-04 - mae: 0.0181 - val_loss: 0.0150 - val_mae: 0.1136
# Epoch 84/100
# 31/31 [==============================] - 1s 18ms/step - loss: 5.9139e-04 - mae: 0.0185 - val_loss: 0.0159 - val_mae: 0.1169
# Epoch 85/100
# 31/31 [==============================] - 1s 22ms/step - loss: 5.8745e-04 - mae: 0.0188 - val_loss: 0.0136 - val_mae: 0.1071
# Epoch 86/100
# 31/31 [==============================] - 1s 21ms/step - loss: 6.3354e-04 - mae: 0.0194 - val_loss: 0.0147 - val_mae: 0.1124
# Epoch 87/100
# 31/31 [==============================] - 1s 19ms/step - loss: 6.1501e-04 - mae: 0.0191 - val_loss: 0.0095 - val_mae: 0.0878
# Epoch 88/100
# 31/31 [==============================] - 1s 18ms/step - loss: 5.2591e-04 - mae: 0.0178 - val_loss: 0.0137 - val_mae: 0.1089
# Epoch 89/100
# 31/31 [==============================] - 1s 19ms/step - loss: 5.6805e-04 - mae: 0.0183 - val_loss: 0.0079 - val_mae: 0.0785
# Epoch 90/100
# 31/31 [==============================] - 1s 19ms/step - loss: 6.3530e-04 - mae: 0.0193 - val_loss: 0.0121 - val_mae: 0.0993
# Epoch 91/100
# 31/31 [==============================] - 1s 18ms/step - loss: 5.8584e-04 - mae: 0.0185 - val_loss: 0.0158 - val_mae: 0.1167
# Epoch 92/100
# 31/31 [==============================] - 1s 20ms/step - loss: 6.1615e-04 - mae: 0.0192 - val_loss: 0.0114 - val_mae: 0.0966
# Epoch 93/100
# 31/31 [==============================] - 1s 20ms/step - loss: 5.7324e-04 - mae: 0.0186 - val_loss: 0.0166 - val_mae: 0.1196
# Epoch 94/100
# 31/31 [==============================] - 1s 22ms/step - loss: 5.6997e-04 - mae: 0.0186 - val_loss: 0.0119 - val_mae: 0.0996
# Epoch 95/100
# 31/31 [==============================] - 1s 19ms/step - loss: 5.5347e-04 - mae: 0.0181 - val_loss: 0.0157 - val_mae: 0.1160
# Epoch 96/100
# 31/31 [==============================] - 1s 21ms/step - loss: 5.4061e-04 - mae: 0.0178 - val_loss: 0.0147 - val_mae: 0.1126
# Epoch 97/100
# 31/31 [==============================] - 1s 20ms/step - loss: 5.4227e-04 - mae: 0.0177 - val_loss: 0.0151 - val_mae: 0.1143
# Epoch 98/100
# 31/31 [==============================] - 1s 23ms/step - loss: 6.0269e-04 - mae: 0.0190 - val_loss: 0.0171 - val_mae: 0.1218
# Epoch 99/100
# 31/31 [==============================] - 1s 25ms/step - loss: 5.0929e-04 - mae: 0.0171 - val_loss: 0.0165 - val_mae: 0.1197
# Epoch 100/100
# 31/31 [==============================] - 1s 20ms/step - loss: 5.6421e-04 - mae: 0.0184 - val_loss: 0.0126 - val_mae: 0.1033

# %%
# Predict
y_pred = improved_gru_model.predict(X_val)

# Inverse transform to original scale
y_pred = y_scaler.inverse_transform(y_pred)
y_val = y_scaler.inverse_transform(y_val)

# Reconstruct the time index for plotting
index = stock_df.index[-len(y_val):]
# Out:
# 8/8 [==============================] - 1s 6ms/step

# %%
# Plot
plt.figure(figsize=(12, 5))
plt.plot(index, y_val, label='True')
plt.plot(index, y_pred, label='Improved Stacked GRU', linestyle='--')
plt.title('Improved Stacked GRU Forecast vs True')
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.legend()
plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error, r2_score

improved_gru_rmse = np.sqrt(mean_squared_error(y_val, y_pred))
improved_gru_mae = mean_absolute_error(y_val, y_pred)
improved_gru_mape = mean_absolute_percentage_error(y_val, y_pred)
improved_gru_r2 = r2_score(y_val, y_pred)

print("📊 Improved GRU Performance:")
print(f"RMSE: {improved_gru_rmse:.4f}")
print(f"MAE: {improved_gru_mae:.4f}")
print(f"MAPE: {improved_gru_mape:.4%}")
print(f"R² Score: {improved_gru_r2:.4f}")
# Out:
# 📊 Improved GRU Performance:
# RMSE: 12.7769
# MAE: 11.7543
# MAPE: 8.9451%
# R² Score: 0.2839

# %% [markdown]
# #### 🔍 Why Performance Can Drop with Deeper GRU Models
#
# - **Overfitting Risk**
#   More layers → More parameters → Higher chance of overfitting, especially with limited or noisy data.
#
# - **Vanishing Gradients**
#   Even with GRUs, deeper RNNs can suffer from vanishing gradients, making it harder for early layers to learn.
#
# - **Hyperparameter Sensitivity**
#   Deeper models are more sensitive to learning rate, dropout, and other hyperparameters. Default settings may not work well.
#
# - **Information Dilution**
#   Stacking too many GRU layers can distort or bury important temporal patterns.
#
# The 2-layer **Stacked GRU** showed the best performance — capturing meaningful patterns without overcomplicating the structure.
#
# **More depth ≠ better**. The optimal architecture depends on the data’s size, complexity, and noise level.

# %% [markdown]
# ### 5-3. Comparison with Traditional Models
#
# - Conduct quantitative comparisons with baseline models like Linear Regression or ARIMA.
# - To ensure fairness, use the same feature set, same prediction target, and same window size across all models.

# %% [markdown]
# ### ARIMA
#
# *While the GRU model is built to leverage multiple input features, the ARIMA model is fundamentally a univariate time series model that relies solely on the past values of a single variable typically the closing price.*
#
# *This distinction highlights the advantage of deep learning models like GRU in capturing complex, multivariate patterns that traditional models like ARIMA are not designed to handle.*

# %%
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score, mean_absolute_percentage_error

# %%
# ARIMA works with a 1D time series only.
# Extract the closing price (or shifted target like next_day_close)
close_series = stock_df['Close'].copy()

# Ensure frequency is explicitly set and consistent
close_series = close_series.asfreq('B')           # Insert missing business days
close_series = close_series.dropna()              # Drop NaNs
close_series.index = pd.date_range(start=close_series.index[0],
                                    periods=len(close_series),
                                    freq='B')      # Set clean business day index

# Set prediction gap D = 5 (5 days ahead prediction)
D = 5
close_series_shifted = close_series.shift(-D)  # Shift target 5 steps earlier

# Drop the last D rows which now have NaN in the target
close_series = close_series[:-D]
close_series_shifted = close_series_shifted.dropna()

# Split into train/test
arima_train_size = int(len(close_series) * 0.8)
arima_train = close_series[:arima_train_size]
arima_test_true = close_series_shifted[arima_train_size:]  # True y values (5 days ahead)
test_start = arima_train_size
test_len = len(arima_test_true)

# Define and fit the ARIMA model (example: ARIMA(5,1,0))
arima_model = ARIMA(arima_train, order=(5, 1, 0))
arima_model_fit = arima_model.fit()

# Forecast the next n steps (equal to the length of the test set)
arima_forecast = arima_model_fit.forecast(steps=test_len)
arima_forecast.index = arima_test_true.index  # align index for plotting

# Evaluate model performance using common regression metrics
arima_rmse = np.sqrt(mean_squared_error(arima_test_true, arima_forecast))
arima_mae = mean_absolute_error(arima_test_true, arima_forecast)
arima_mape = mean_absolute_percentage_error(arima_test_true, arima_forecast)
arima_r2 = r2_score(arima_test_true, arima_forecast)

print(f"📈 ARIMA Evaluation:")
print(f"RMSE: {arima_rmse:.4f}")
print(f"MAE: {arima_mae:.4f}")
print(f"MAPE: {arima_mape:.2%}")
print(f"R² Score: {arima_r2:.4f}")

# Visualize the true vs. predicted values
plt.figure(figsize=(12, 5))
plt.plot(arima_test_true.index, arima_test_true, label='True')
plt.plot(arima_forecast.index, arima_forecast, label='ARIMA Prediction', linestyle='--')
plt.title('ARIMA Forecast vs True')
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# 📈 ARIMA Evaluation:
# RMSE: 25.7885
# MAE: 20.8114
# MAPE: 15.20%
# R² Score: -1.8671

# %% [markdown]
# ### Multivariate Linear Regression

# %%
from sklearn.linear_model import LinearRegression

# %%
# Define features and target
lr_feature_cols = [
    'price_lag1', 'price_lag2', 'return_lag1',
    'SMA_5', 'SMA_20', 'EMA_20', 'RSI_14',
    'MACD', 'MACD_signal', 'roll_std5',
    'volatility_5', 'volatility_20', 'vol_ratio'
]
stock_df['next_5day_close'] = stock_df['Close'].shift(-5)
lr_target_col = 'next_5day_close'

# Drop missing values
data = stock_df.copy()
data = data.dropna(subset=lr_feature_cols + [lr_target_col])

# Split into train/test
lr_train_size = int(len(data) * 0.8)
lr_train, lr_test = data.iloc[:lr_train_size], data.iloc[lr_train_size:]

lr_X_train = lr_train[lr_feature_cols]
lr_X_test = lr_test[lr_feature_cols]
lr_y_train = lr_train[lr_target_col]
lr_y_test = lr_test[lr_target_col]

# Fit Linear Regression model
lr_model = LinearRegression()
lr_model.fit(lr_X_train, lr_y_train)

# Predict
lr_y_pred = lr_model.predict(lr_X_test)

# Evaluation
lr_rmse = np.sqrt(mean_squared_error(lr_y_test, lr_y_pred))
lr_mae = mean_absolute_error(lr_y_test, lr_y_pred)
lr_mape = mean_absolute_percentage_error(lr_y_test, lr_y_pred)
lr_r2 = r2_score(lr_y_test, lr_y_pred)

print("📊 Multivariate Linear Regression Performance:")
print(f"RMSE: {lr_rmse:.4f}")
print(f"MAE: {lr_mae:.4f}")
print(f"MAPE: {lr_mape:.2%}")
print(f"R² Score: {lr_r2:.4f}")

# Visualization
plt.figure(figsize=(12, 5))
plt.plot(lr_y_test.index, lr_y_test, label='True')
plt.plot(lr_y_test.index, lr_y_pred, label='Predicted (LR)', linestyle='--')
plt.title('Linear Regression Forecast vs True')
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# 📊 Multivariate Linear Regression Performance:
# RMSE: 3.8458
# MAE: 3.1353
# MAPE: 2.42%
# R² Score: 0.9362

# %%
plt.figure(figsize=(14, 6))

# Actual closing
plt.plot(gru_index, gru_y_val, label='True Price', color='black')

# GRU
plt.plot(gru_index, gru_y_pred, label='GRU', linestyle='--', color='green')

# Stacked GRU
plt.plot(gru_index, stacked_gru_y_pred, label='Stacked GRU', linestyle='--', color='darkgreen')

# Linear Regression
plt.plot(lr_y_test.index[-len(gru_index):], lr_y_pred[-len(gru_index):], label='Linear Regression', linestyle='--', color='blue')

# ARIMA
plt.plot(arima_forecast.index[-len(gru_index):], arima_forecast[-len(gru_index):], label='ARIMA', linestyle='--', color='orange')

# Formatting
plt.title('Model Comparison: GRU vs Stacked GRU vs Linear Regression vs ARIMA')
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# #### 📊 Interpretation
#
# - **Linear Regression**, while simple, shows **outstanding performance** even with a 5-day prediction horizon (D=5), achieving an **R² of 0.98**. It captures both the overall trend and magnitude very accurately.
#
# - **GRU and Stacked GRU** models still seem to **underfit**, likely due to insufficient model capacity or lack of informative features. There is clear room for improvement.
#
# - **ARIMA** is generally good for univariate time-series forecasting but struggles here because it only uses the `Close` variable. As a result, its prediction is **static and slow to respond**.
#
# #### ✅ Suggested Next Steps
#
# **🔁 GRU Enhancements**
# - Increase model depth (e.g., 3 GRU layers or residual GRU structures)
# - Add more predictive features (e.g., **volume change rate**, **Bollinger Bands**, etc.)
# - Try **hybrid architectures** such as **CNN-GRU** or **GRU + Attention**
#
# **⚖️ Keep Linear Regression as a Strong Baseline**
# - Emphasize its performance in the report as a **"surprisingly strong baseline"**
#
# **🔄 Consider Reformulating the Task as a Classification Problem**
# - Instead of predicting future price values, **predict price direction** (up/down)
# - This may better align with the nature of GRU models
# - Evaluate using **accuracy, F1-score**, and **confusion matrix**

# %% [markdown]
# ### 5-4. Applying to Other Stocks (Scalability)
#
# - Test the model on other ASX stocks such as BHP, NAB, or WBC to evaluate its scalability and generalizability.

# %% [markdown]
# ### 5.5. Conversion to Classification (Trend Prediction)
#
# - Convert the regression target into binary labels, e.g., `price_change` > 0 → 1 (up), else → 0 (down).
# - The model’s goal becomes predicting **whether the stock price will rise.**
# - Evaluate performance using **accuracy, F1-score, and confusion matrix.**
