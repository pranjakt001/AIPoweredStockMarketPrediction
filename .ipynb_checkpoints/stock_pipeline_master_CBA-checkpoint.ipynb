# %% [markdown]
# #### Outline
# 1. Data collection
# 2. Feature Engineering
# 3. Input Construction
# 4. Modeling
#    - Quantatitive Evaluation (RMSE, MAE, MAPE, $R^2$)
#    - Explainability (SHAP, Grad-CAM)
# 5. Financial Evaluation (Sharpe Ratio, Cumulative Return)

# %% [markdown]
# ## 1. Data collection - Individual Stocks

# %% [markdown]
# ### Setting Random Seeds
#
# To ensure reproducible results across different runs of the model, we explicitly set random seeds at multiple levels.
# These help guarantee that:
#
# - the data splits,
# - the weight initialization,
# - and other stochastic operations in the pipeline
#
# produce the same output everytime the code is run, assuming the same hardware and software environment.
#
# This is especially important when comparing model performance, tuning hyperparameters, or performing SHAP explainability.

# %%
import os
import random
import numpy as np
import tensorflow as tf

def set_global_seed(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    tf.random.set_seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    os.environ['TF_DETERMINISTIC_OPS'] = '1'
    tf.config.threading.set_intra_op_parallelism_threads(1)
    tf.config.threading.set_inter_op_parallelism_threads(1)

set_global_seed(42)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# -------------------------
# Dummy Model Builder
# -------------------------
def build_and_train_model():
    # Dummy input and output
    X = np.random.rand(100, 5)
    y = (X.sum(axis=1) > 2.5).astype(int)

    # Define a simple model
    model = Sequential([
        Dense(16, activation='relu', input_shape=(5,)),
        Dense(1, activation='sigmoid')
    ])
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    model.fit(X, y, epochs=10, batch_size=8, verbose=0)
    
    # Make prediction on new input
    test_input = np.random.rand(1, 5)
    prediction = model.predict(test_input)
    return prediction

# -------------------------
# Run Twice with Same Seed
# -------------------------
set_global_seed(42)
pred1 = build_and_train_model()

set_global_seed(42)
pred2 = build_and_train_model()

# -------------------------
# Compare Results
# -------------------------
print("First prediction:", pred1.flatten())
print("Second prediction:", pred2.flatten())
print("Are they equal?", np.allclose(pred1, pred2, atol=1e-6))
# Out:
# C:\Users\jiyoo\anaconda3\envs\tf_env\lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# First prediction: [0.5427954]
# Second prediction: [0.5427954]
# Are they equal? True

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

# %%
ticker = "CBA"

df = pd.read_csv("combined_stock_data.csv", parse_dates=['Date'])
stock_df = df[df['Name'] == ticker].copy()

# Sort by date
stock_df.sort_values(by='Date', inplace=True)

# Set index
stock_df.set_index('Date', inplace=True)


# Missing values
print("\n Missing values:")
print(stock_df.isnull().sum())  # Count missing values per column
stock_df.dropna(inplace=True)

# Check column and head
print(stock_df.columns)
print(stock_df.head())

# Check the number of rows
freq_counts = stock_df['Name'].value_counts()
print(freq_counts.describe())
# Out:
#  Missing values:
# Open      0
# High      0
# Low       0
# Close     0
# Volume    0
# Name      0
# dtype: int64
# Index(['Open', 'High', 'Low', 'Close', 'Volume', 'Name'], dtype='object')
#                  Open       High        Low      Close   Volume Name
# Date
# 2020-01-02  64.860162  65.209704  64.535007  64.933319  1416232  CBA
# 2020-01-03  65.819375  65.998211  65.234096  65.282867  1622784  CBA
# 2020-01-06  64.811385  64.933313  64.404942  64.843895  2129260  CBA
# 2020-01-07  65.697438  66.006332  65.177192  66.006332  2417468  CBA
# 2020-01-08  66.022597  66.046983  65.055261  65.762474  1719114  CBA
# count       1.0
# mean     1266.0
# std         NaN
# min      1266.0
# 25%      1266.0
# 50%      1266.0
# 75%      1266.0
# max      1266.0
# Name: count, dtype: float64

# %% [markdown]
# ## 📊 2. Features Engineering
#
# These features combine classic time series lags, trend indicators, momentum oscillators, and volatility metrics.
# Grouped below by functional type, they provide rich information for both interpretable models and deep learning models like GRU.
#
# ---
#
# ### 🕒 Lag Features
# Understand **short-term behavior** via lags and returns.
#
# | Column Name     | Description |
# |-----------------|-------------|
# | **price_lag1**   | Closing price from 1 day ago – captures immediate price momentum |
# | **price_lag2**   | Closing price from 2 days ago – extends short-term memory |
# | **return_lag1**  | Percentage return from 1 day ago – normalized price change (%) |
#
# ---
#
# ### 📈 Trend Indicators
# Capture **trend direction and reversals** using SMA, EMA, and price deviation.
#
# | Column Name     | Description |
# |-----------------|-------------|
# | **SMA_5**        | 5-day Simple Moving Average – short-term trend average |
# | **SMA_20**       | 20-day Simple Moving Average – long-term trend reference |
# | **EMA_20**       | 20-day Exponential Moving Average – reacts faster to recent prices |
# | **norm_price**   | Price deviation (%) from 20-day MA – normalized position relative to trend |
#
# ---
#
# ### 🔄 Momentum Indicators
# Measure **momentum and overbought/oversold conditions** via RSI and MACD.
#
# | Column Name     | Description |
# |-----------------|-------------|
# | **RSI_14**       | 14-day Relative Strength Index – momentum oscillator (0–100 scale). Overbought if >70, Oversold if <30 |
# | **MACD**         | Moving Average Convergence Divergence – difference between EMA(12) and EMA(26), indicates momentum direction |
# | **MACD_signal**  | 9-day EMA of MACD – signal line used for MACD crossover buy/sell decisions |
#
# ---
#
# ### 🌊 Volatility Features
# Quantify **volatility and risk** using standard deviation and volatility ratios.
#
# | Column Name       | Description |
# |-------------------|-------------|
# | **roll_std5**      | 5-day rolling standard deviation – short-term volatility indicator |
# | **volatility_5**   | Standard deviation of 5-day returns – recent volatility measure |
# | **volatility_20**  | Standard deviation of 20-day returns – longer-term volatility context |
# | **vol_ratio**      | Ratio of short-term to long-term volatility (`vol_5 / vol_20`) – reflects market stability shifts |

# %%
# Compute daily returns as percentage change in closing price
stock_df['returns'] = stock_df['Close'].pct_change() * 100

# ------------------------------------------
# 🕒 Lag Features
# ------------------------------------------
stock_df['price_lag1'] = stock_df['Close'].shift(1)
stock_df['price_lag2'] = stock_df['Close'].shift(2)
stock_df['return_lag1'] = stock_df['returns'].shift(1)

# ------------------------------------------
# 📈 Trend Indicators
# ------------------------------------------
stock_df['SMA_5'] = stock_df['Close'].rolling(window=5).mean()
stock_df['SMA_20'] = stock_df['Close'].rolling(window=20).mean()
stock_df['EMA_20'] = stock_df['Close'].ewm(span=20, adjust=False).mean()
stock_df['norm_price'] = (stock_df['Close'] - stock_df['SMA_20']) / stock_df['SMA_20'] * 100

# ------------------------------------------
# 🔄 Momentum Indicators
# ------------------------------------------

# RSI (14-day)
delta = stock_df['Close'].diff()
gain = (delta.where(delta > 0, 0)).fillna(0)
loss = (-delta.where(delta < 0, 0)).fillna(0)

avg_gain = gain.rolling(window=14).mean()
avg_loss = loss.rolling(window=14).mean()

rs = avg_gain / avg_loss
stock_df['RSI_14'] = 100 - (100 / (1 + rs))

# MACD and Signal Line
ema_12 = stock_df['Close'].ewm(span=12, adjust=False).mean()
ema_26 = stock_df['Close'].ewm(span=26, adjust=False).mean()
stock_df['MACD'] = ema_12 - ema_26
stock_df['MACD_signal'] = stock_df['MACD'].ewm(span=9, adjust=False).mean()

# ------------------------------------------
# 🌊 Volatility Features
# ------------------------------------------
stock_df['roll_std5'] = stock_df['Close'].rolling(window=5).std()
stock_df['volatility_5'] = stock_df['returns'].rolling(window=5).std()
stock_df['volatility_20'] = stock_df['returns'].rolling(window=20).std()
stock_df['vol_ratio'] = stock_df['volatility_5'] / stock_df['volatility_20'].replace(0, np.nan)

# %%
# Missing values
print("\n Missing values:")
print(stock_df.isnull().sum())
# Out:
#  Missing values:
# Open              0
# High              0
# Low               0
# Close             0
# Volume            0
# Name              0
# returns           1
# price_lag1        1
# price_lag2        2
# return_lag1       2
# SMA_5             4
# SMA_20           19
# EMA_20            0
# norm_price       19
# RSI_14           13
# MACD              0
# MACD_signal       0
# roll_std5         4
# volatility_5      5
# volatility_20    20
# vol_ratio        20
# dtype: int64

# %% [markdown]
# It's normal for rolling and shift-based indicators to have NaN values in the initial rows, since they require **past data** to compute.
#
# Especially for models like GRU or CNN where the sequence order is important,
# it's common practice to **drop** those initial rows with missing values before training the model.

# %%
stock_df.dropna(inplace=True)
print("Final shape after dropping NaNs:", stock_df.shape)
# Out:
# Final shape after dropping NaNs: (1246, 21)

# %%
import matplotlib.pyplot as plt

# %%
# ----------------------------------------
# 1. Price with SMA & EMA - Helps identify short- and long-term trend movements
# ----------------------------------------
plt.figure(figsize=(14, 6))
plt.plot(stock_df['Close'], label='Close Price', color='black')
plt.plot(stock_df['SMA_20'], label='SMA 20', linestyle='--')
plt.plot(stock_df['EMA_20'], label='EMA 20', linestyle='-.')
plt.title('Close Price with SMA and EMA')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.tight_layout()
plt.show()

# ----------------------------------------
# 2. RSI - Detects potential overbought and oversold conditions for timing entries/exits
# ----------------------------------------
plt.figure(figsize=(14, 4))
plt.plot(stock_df['RSI_14'], label='RSI 14', color='purple')
plt.axhline(70, color='red', linestyle='--', label='Overbought (70)')
plt.axhline(30, color='green', linestyle='--', label='Oversold (30)')
plt.title('RSI (Relative Strength Index)')
plt.xlabel('Date')
plt.ylabel('RSI')
plt.legend()
plt.tight_layout()
plt.show()

# ----------------------------------------
# 3. MACD - Highlights possible trend reversal signals through line crossovers
# ----------------------------------------
plt.figure(figsize=(14, 5))
plt.plot(stock_df['MACD'], label='MACD', color='blue')
plt.plot(stock_df['MACD_signal'], label='Signal Line', color='orange')
plt.axhline(0, color='gray', linestyle='--')
plt.title('MACD and Signal Line')
plt.xlabel('Date')
plt.ylabel('MACD Value')
plt.legend()
plt.tight_layout()
plt.show()

# ----------------------------------------
# 4. Volatility: rolling std and volatility ratio - Reveals market instability and periods of sharp fluctuations
# ----------------------------------------
plt.figure(figsize=(14, 5))
plt.plot(stock_df['volatility_5'], label='Volatility (5-day)', color='teal')
plt.plot(stock_df['volatility_20'], label='Volatility (20-day)', color='coral')
plt.title('Short vs Long-Term Volatility')
plt.xlabel('Date')
plt.ylabel('Volatility')
plt.legend()
plt.tight_layout()
plt.show()

plt.figure(figsize=(14, 4))
plt.plot(stock_df['vol_ratio'], label='Volatility Ratio (5d/20d)', color='brown')
plt.title('Volatility Ratio (5-day / 20-day)')
plt.xlabel('Date')
plt.ylabel('Ratio')
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 3. Input Construction
#
# ### Objective
# Use the past **N day** of time-series as input **X**, and predict either the **closing price D days ahead** or the **price direction (up/down)** as output **Y**.
#
# ### Example Setting
# - `N = 30`: Use the past 30 days of data as input
# - `D = 5`: Predict the closing price (or direction) 5 days into the future
#
# ### Required Features
# To construct effective input sequences, we include the following engineered features:
#
# - Lag-based prices and returns: `price_lag1`, `return_lag1`, etc.
# - Trend indicators: `SMA_5`, `EMA_20`, `norm_price`
# - Momentum indicators: `RSI_14`, `MACD`, `MACD_signal`
# - Volatility metrics: `volatility_5`, `vol_ratio`
#
# The features are normalized or scaled where necessary to ensure stability in model training.

# %%
def create_sequences(data, target_col, N=30, D=1, task='regression'):
    """
    Create input-output sequences for time-series models like GRU or CNN.

    Parameters:
    - data: pandas DataFrame with time-series features
    - target_col: column name to be predicted (e.g., 'Close')
    - N: number of days to use as input (sequence length)
    - D: number of days ahead to predict
    - task: 'regression' or 'classification'

    Returns:
    - X: 3D numpy array (samples, N, features)
    - y: 1D or 2D numpy array of targets
    """

    X = []
    y = []

    features = data.drop(columns=[target_col]).values
    target = data[target_col].values

    for i in range(len(data) - N - D + 1):
        X_seq = features[i:i+N]
        if task == 'regression':
            y_label = target[i+N+D-1]  # Predict D days ahead closing price
        elif task == 'classification':
            y_label = 1 if target[i+N+D-1] > target[i+N-1] else 0  # Price up or down
        else:
            raise ValueError("Task must be 'regression' or 'classification'")

        X.append(X_seq)
        y.append(y_label)

    return np.array(X), np.array(y)

# %% [markdown]
# Ensure that only historical data is used to predict future values, in line with the principle of time series forecasting.
# - **X**: The past **N days** of input data (e.g., from index `i` to `i+N-1`, representing up to time **t**
# - **y**: The target value at **D days after** the input window (i.e., at index `i+N+D-1`), representing a **future time step to be predicted**

# %%
feature_cols = ['Volume', 'Open', 'High', 'Low', 'RSI_14', 'MACD', 'MACD_signal',
            'SMA_5', 'SMA_20', 'EMA_20', 'norm_price', 'price_lag1', 'price_lag2',
            'return_lag1', 'volatility_5', 'volatility_20', 'vol_ratio']

target_col = 'Close'  # For regression
seq_df = stock_df[feature_cols + [target_col]].dropna().copy()

# Create sequences
X, y = create_sequences(seq_df, target_col=target_col, N=30, D=1, task='regression')

print("✅ Sequences created:")
print("X shape:", X.shape)  # (samples, 30, features)
print("y shape:", y.shape)  # (samples,)
# Out:
# ✅ Sequences created:
# X shape: (1216, 30, 17)
# y shape: (1216,)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import GRU, Dense, Dropout
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.optimizers import Adam

# %% [markdown]
# ### Data Preprocessing

# %%
# Feature scaling (optional but recommended for GRU)
X_reshaped = X.reshape(-1, X.shape[-1])  # (1212*30, 13)
X_scaler = MinMaxScaler()
X_scaled = X_scaler.fit_transform(X_reshaped)
X_scaled = X_scaled.reshape(X.shape)  # (1212, 30, 13)

# y scaling (for regression)
y = y.reshape(-1, 1)
y_scaler = MinMaxScaler()
y_scaler.fit(y)  # fit only once
y_scaled = y_scaler.transform(y)  # transform separately

# %% [markdown]
# ### Train/Validation Split for Time Series

# %%
split_index = int(len(X_scaled) * 0.8)

# Training set: the first 80% of the sequence
X_train = X_scaled[:split_index]
y_train = y_scaled[:split_index]

# Validation set: the most recent 20%
X_val = X_scaled[split_index:]
y_val = y_scaled[split_index:]
val_dates = stock_df.index[-len(y_val):]

print("X_train shape:", X_train.shape)
print("X_val shape:", X_val.shape)
# Out:
# X_train shape: (972, 30, 17)
# X_val shape: (244, 30, 17)

# %% [markdown]
# - The temporal sequence must not be broken.
# - **Using recent data as validation** allows us to test how the model would behave on unseen, future-like data.
# - Once the model architecture is reasonably finaised, expand to **TimeSeriesSplit** for evaluating performance stability and implementing cross-validated GRU training.

# %% [markdown]
# ## 4. Modeling

# %% [markdown]
# ### 4-1. Build GRU model

# %%
# Set input dimensions
timesteps = X_train.shape[1]  # ➜ 30 (N-day input window)
features = X_train.shape[2]   # ➜ 13 (number of input features per time step)

# Build GRU model
gru_model = Sequential([
    GRU(64, input_shape=(timesteps, features), return_sequences=False), # Encodes the input sequence into a 64-dimensional representation
    Dropout(0.2), # Randomly drops a portion of the units during training to prevent overfitting
    Dense(32, activation='relu'), # Fully connected layer
    Dense(1)  # Regression output
])

gru_model.compile(
    optimizer=Adam(learning_rate=0.001),
    loss='mse',
    metrics=['mae']
)

gru_model.summary()
# Out:
# C:\Users\jiyoo\anaconda3\envs\tf_env\lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ gru (GRU)                       │ (None, 64)             │        15,936 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 18,049 (70.50 KB)
#  Trainable params: 18,049 (70.50 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### Train GRU model

# %% [markdown]
# - `loss`: Mean Squared Error (MSE) on the training set
# - `val_loss`: Mean Squared Error (MSE) on the validation set
#
# **🧠 Interpretation Guide**
#
# | Pattern                | Interpretation                                                                 |
# |------------------------|---------------------------------------------------------------------------------|
# | `loss ↓`, `val_loss ↓` | The model is learning well and improving over time                            |
# | `loss ↓`, `val_loss ↑` | Possible overfitting – the model fits training data well but does not generalize  |
# | `loss ≈ val_loss`, high values | Stable learning but performance still has room for improvement               |
#
#
# **✅ MAE (Mean Absolute Error)**
#
# If `metrics=['mae']` is specified during model compilation,
# then `val_mae` represents the **average absolute difference** between predicted and actual values on the validation set.
#
# **📈 Predicted vs Actual Plot Patterns**
#
# | Pattern                                  | Interpretation                                                              |
# |------------------------------------------|------------------------------------------------------------------------------|
# | Lines closely overlap                    | Strong prediction performance                                             |
# | Trend is correct but scale is off       | Scaling or normalization might need adjustment                             |
# | Predictions are flat or unresponsive     | Model may be too simple or input sequence too short                        |
# | Predictions fluctuate excessively        | Possible overfitting or noisy data                                          |

# %%
history = gru_model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=50,
    batch_size=32,
    verbose=1, # Display training progress during each epoch
    shuffle=False # Disable shuffling to preserve time series order
)
# Out:
# Epoch 1/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - loss: 0.0171 - mae: 0.1029 - val_loss: 0.0191 - val_mae: 0.1185
# Epoch 2/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0125 - mae: 0.0940 - val_loss: 0.0080 - val_mae: 0.0743
# Epoch 3/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0053 - mae: 0.0588 - val_loss: 0.0030 - val_mae: 0.0470
# Epoch 4/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0042 - mae: 0.0522 - val_loss: 0.0028 - val_mae: 0.0436
# Epoch 5/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0030 - mae: 0.0407 - val_loss: 0.0095 - val_mae: 0.0907
# Epoch 6/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0015 - mae: 0.0300 - val_loss: 0.0050 - val_mae: 0.0632
# Epoch 7/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0013 - mae: 0.0285 - val_loss: 0.0079 - val_mae: 0.0831
# Epoch 8/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0015 - mae: 0.0307 - val_loss: 0.0080 - val_mae: 0.0825
# Epoch 9/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0014 - mae: 0.0284 - val_loss: 0.0087 - val_mae: 0.0874
# Epoch 10/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0014 - mae: 0.0291 - val_loss: 0.0086 - val_mae: 0.0865
# Epoch 11/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0010 - mae: 0.0248 - val_loss: 0.0080 - val_mae: 0.0833
# Epoch 12/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 8.3700e-04 - mae: 0.0231 - val_loss: 0.0101 - val_mae: 0.0947
# Epoch 13/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 8.6445e-04 - mae: 0.0234 - val_loss: 0.0093 - val_mae: 0.0900
# Epoch 14/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 9.3202e-04 - mae: 0.0239 - val_loss: 0.0106 - val_mae: 0.0963
# Epoch 15/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 8.9780e-04 - mae: 0.0233 - val_loss: 0.0112 - val_mae: 0.0991
# Epoch 16/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 8.9722e-04 - mae: 0.0231 - val_loss: 0.0064 - val_mae: 0.0734
# Epoch 17/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0010 - mae: 0.0247 - val_loss: 0.0110 - val_mae: 0.0978
# Epoch 18/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 9.1573e-04 - mae: 0.0233 - val_loss: 0.0063 - val_mae: 0.0717
# Epoch 19/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 6.7872e-04 - mae: 0.0208 - val_loss: 0.0104 - val_mae: 0.0947
# Epoch 20/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 8.0830e-04 - mae: 0.0225 - val_loss: 0.0052 - val_mae: 0.0652
# Epoch 21/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0011 - mae: 0.0260 - val_loss: 0.0027 - val_mae: 0.0444
# Epoch 22/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0017 - mae: 0.0331 - val_loss: 0.0040 - val_mae: 0.0582
# Epoch 23/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0016 - mae: 0.0330 - val_loss: 0.0067 - val_mae: 0.0768
# Epoch 24/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0012 - mae: 0.0275 - val_loss: 0.0119 - val_mae: 0.1033
# Epoch 25/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0019 - mae: 0.0358 - val_loss: 0.0057 - val_mae: 0.0657
# Epoch 26/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 9.2227e-04 - mae: 0.0230 - val_loss: 0.0076 - val_mae: 0.0798
# Epoch 27/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 8.1736e-04 - mae: 0.0226 - val_loss: 0.0116 - val_mae: 0.1010
# Epoch 28/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 5.6896e-04 - mae: 0.0181 - val_loss: 0.0120 - val_mae: 0.1012
# Epoch 29/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 9.8137e-04 - mae: 0.0248 - val_loss: 0.0106 - val_mae: 0.0954
# Epoch 30/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 7.7430e-04 - mae: 0.0223 - val_loss: 0.0065 - val_mae: 0.0725
# Epoch 31/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 7.4743e-04 - mae: 0.0216 - val_loss: 0.0104 - val_mae: 0.0950
# Epoch 32/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 8.5848e-04 - mae: 0.0230 - val_loss: 0.0110 - val_mae: 0.0974
# Epoch 33/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 5.9275e-04 - mae: 0.0185 - val_loss: 0.0128 - val_mae: 0.1065
# Epoch 34/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 5.0830e-04 - mae: 0.0172 - val_loss: 0.0111 - val_mae: 0.0982
# Epoch 35/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 5.3609e-04 - mae: 0.0181 - val_loss: 0.0079 - val_mae: 0.0827
# Epoch 36/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 7.8420e-04 - mae: 0.0222 - val_loss: 0.0106 - val_mae: 0.0964
# Epoch 37/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 6.2146e-04 - mae: 0.0191 - val_loss: 0.0125 - val_mae: 0.1057
# Epoch 38/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 4.6746e-04 - mae: 0.0169 - val_loss: 0.0114 - val_mae: 0.0994
# Epoch 39/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 7.3573e-04 - mae: 0.0206 - val_loss: 0.0083 - val_mae: 0.0851
# Epoch 40/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 6.3966e-04 - mae: 0.0200 - val_loss: 0.0102 - val_mae: 0.0954
# Epoch 41/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 6.2956e-04 - mae: 0.0195 - val_loss: 0.0124 - val_mae: 0.1050
# Epoch 42/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 5.6153e-04 - mae: 0.0181 - val_loss: 0.0096 - val_mae: 0.0922
# Epoch 43/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step - loss: 5.6955e-04 - mae: 0.0186 - val_loss: 0.0121 - val_mae: 0.1038
# Epoch 44/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 4.4712e-04 - mae: 0.0167 - val_loss: 0.0127 - val_mae: 0.1066
# Epoch 45/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 4.5232e-04 - mae: 0.0166 - val_loss: 0.0124 - val_mae: 0.1059
# Epoch 46/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 3.8493e-04 - mae: 0.0153 - val_loss: 0.0099 - val_mae: 0.0936
# Epoch 47/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 3.9714e-04 - mae: 0.0158 - val_loss: 0.0103 - val_mae: 0.0952
# Epoch 48/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 4.5560e-04 - mae: 0.0165 - val_loss: 0.0086 - val_mae: 0.0872
# Epoch 49/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 5.4434e-04 - mae: 0.0182 - val_loss: 0.0062 - val_mae: 0.0732
# Epoch 50/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 8.3646e-04 - mae: 0.0231 - val_loss: 0.0050 - val_mae: 0.0649

# %% [markdown]
# ### Prediction and Visualisation
# *The model trains on normalised data above, while interpretation is done on the original scale.*
#
# *Make sure to use `X` and `y` generated after `.dropna()`, as mismatched lengths between `y_val` and `y_pred` can cause errors.*
#
# *To zoom in, we can plot a subset like `plt.plot(y_val[:100])` for better visual clarity.*

# %%
# Predict
gru_y_pred = gru_model.predict(X_val)

# Inverse transform
gru_y_pred = y_scaler.inverse_transform(gru_y_pred)
gru_y_val = y_scaler.inverse_transform(y_val)
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step

# %%
# Visualise
plt.figure(figsize=(12, 5))
plt.plot(val_dates, gru_y_val, label='True')
plt.plot(val_dates, gru_y_pred, label='Predicted (GRU)', linestyle='--')
plt.title('GRU Forecast vs True')
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.legend()
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 3))
plt.plot(gru_y_val - gru_y_pred, label='Prediction Error')
plt.title('Prediction Error (True - Predicted)')
plt.xlabel('Time Step')
plt.ylabel('Error')
plt.axhline(0, color='gray', linestyle='--')
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Quantitative Evaluation
# *While we've already reviewed common metrics like **loss, MAE, and val_loss**, it's helpful to include additional evaluation metrics to get a more complete picture of model performance.*
#
# - **RMSE (Root Mean Squared Error)**: Measures the square root of the average squared difference between predicted and actual values. Penalizes large errors more heavily. A lower RMSE indicates better model accuracy.
# - **MAPE (Mean Absolute Percentage Error)**: Expresses prediction error as a percentage of the actual values. It shows, on average, how far off the predictions are in relative terms. Lower is better.
# - **$R^2$ Score (Coefficient of Determination)**: Represents how well the model explains the variance in the target variable. Ranges from 0 to 1 (closer to 1 is better). A negative value means the model performs worse than a horizontal line (mean predictor).

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error, r2_score

# %%
gru_rmse = np.sqrt(mean_squared_error(gru_y_val, gru_y_pred))
gru_mae = mean_absolute_error(gru_y_val, gru_y_pred)
gru_mape = mean_absolute_percentage_error(gru_y_val, gru_y_pred)
gru_r2 = r2_score(gru_y_val, gru_y_pred)

print("📊 GRU Performance:")
print(f"RMSE: {gru_rmse:.4f}")
print(f"MAE: {gru_mae:.4f}")
print(f"MAPE: {gru_mape:.4%}")
print(f"R² Score: {gru_r2:.4f}")
# Out:
# 📊 GRU Performance:
# RMSE: 8.0084
# MAE: 7.3887
# MAPE: 5.6262%
# R² Score: 0.7196

# %%
import shap

# Flatten input for KernelExplainer: [samples, features * timesteps]
X_kernel = X_val[:20].reshape(20, -1)
X_bg = X_train[:50].reshape(50, -1)

# Define a prediction function
def model_predict(x):
    return gru_model.predict(x.reshape(-1, X_train.shape[1], X_train.shape[2]))

explainer = shap.KernelExplainer(model_predict, X_bg)
shap_values_gru = explainer.shap_values(X_kernel, nsamples=200)

# Average feature importance
shap_array = np.abs(shap_values_gru).mean(axis=0)
feature_importance = shap_array.reshape(X_train.shape[1], X_train.shape[2]).mean(axis=0)

# Plot bar chart
plt.figure(figsize=(10, 5))
plt.barh(range(len(feature_cols)), feature_importance, color='orange')
plt.yticks(range(len(feature_cols)), feature_cols)
plt.xlabel("Mean SHAP Value")
plt.title("GRU Model - Feature Importance (Kernel SHAP)")
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
#   0%|          | 0/20 [00:00<?, ?it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step

# %%
top_k = 5
top_indices = np.argsort(feature_importance)[-top_k:]

plt.barh(np.array(feature_cols)[top_indices], feature_importance[top_indices], color='orange')
plt.xlabel("Mean SHAP Value")
plt.title("Top 5 Important Features (GRU SHAP)")
plt.tight_layout()
plt.grid(True)
plt.show()

# %% [markdown]
# ### 4-2. Fine-Tuned GRU

# %%
from tensorflow.keras.callbacks import EarlyStopping

warnings.filterwarnings("ignore")

#Normalize
scaler = MinMaxScaler()
scaled = scaler.fit_transform(stock_df[feature_cols])
scaled_df = pd.DataFrame(scaled, columns=feature_cols, index=stock_df.index)


# Build a fine-tuned GRU model
fine_tuned_gru = Sequential()
fine_tuned_gru.add(GRU(128, return_sequences=True, input_shape=(X.shape[1], X.shape[2])))
fine_tuned_gru.add(Dropout(0.3))
fine_tuned_gru.add(GRU(64))
fine_tuned_gru.add(Dense(32, activation='relu'))
fine_tuned_gru.add(Dense(1))
fine_tuned_gru.compile(optimizer=Adam(0.0005), loss='mse', metrics=['mae'])

# Train
early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
history_fine = fine_tuned_gru.fit(X_train, y_train, validation_data=(X_val, y_val),
                    epochs=100, batch_size=32, callbacks=[early_stop], verbose=1, shuffle=False)

# Predict on validation set
fine_tuned_gru_y_pred = fine_tuned_gru.predict(X_val)

# Inverse transform predictions and targets
fine_tuned_gru_y_pred_inv = y_scaler.inverse_transform(fine_tuned_gru_y_pred)
y_val_inv = y_scaler.inverse_transform(y_val)

# Evaluation metrics
rmse = np.sqrt(mean_squared_error(y_val_inv, fine_tuned_gru_y_pred_inv))
mae = mean_absolute_error(y_val_inv, fine_tuned_gru_y_pred_inv)
r2 = r2_score(y_val_inv, fine_tuned_gru_y_pred_inv)

print(f"📊 Fine-Tuned GRU Performance — RMSE: {rmse:.4f}, MAE: {mae:.4f}, R²: {r2:.4f}")
# Out:
# Epoch 1/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 6s 55ms/step - loss: 0.0039 - mae: 0.0518 - val_loss: 0.0316 - val_mae: 0.1510
# Epoch 2/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0323 - mae: 0.1577 - val_loss: 0.0208 - val_mae: 0.1238
# Epoch 3/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step - loss: 0.0085 - mae: 0.0787 - val_loss: 0.0110 - val_mae: 0.0910
# Epoch 4/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 8.8658e-04 - mae: 0.0234 - val_loss: 0.0117 - val_mae: 0.0942
# Epoch 5/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 8.2858e-04 - mae: 0.0231 - val_loss: 0.0085 - val_mae: 0.0780
# Epoch 6/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 60ms/step - loss: 6.3714e-04 - mae: 0.0199 - val_loss: 0.0072 - val_mae: 0.0715
# Epoch 7/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 6.0910e-04 - mae: 0.0193 - val_loss: 0.0064 - val_mae: 0.0660
# Epoch 8/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 4.9687e-04 - mae: 0.0176 - val_loss: 0.0063 - val_mae: 0.0662
# Epoch 9/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 5.8529e-04 - mae: 0.0192 - val_loss: 0.0059 - val_mae: 0.0640
# Epoch 10/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 6.3678e-04 - mae: 0.0200 - val_loss: 0.0083 - val_mae: 0.0785
# Epoch 11/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 4.6124e-04 - mae: 0.0166 - val_loss: 0.0064 - val_mae: 0.0662
# Epoch 12/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 4.7029e-04 - mae: 0.0172 - val_loss: 0.0054 - val_mae: 0.0604
# Epoch 13/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 60ms/step - loss: 6.4238e-04 - mae: 0.0202 - val_loss: 0.0073 - val_mae: 0.0737
# Epoch 14/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 5.3925e-04 - mae: 0.0181 - val_loss: 0.0078 - val_mae: 0.0747
# Epoch 15/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 4.5890e-04 - mae: 0.0167 - val_loss: 0.0055 - val_mae: 0.0595
# Epoch 16/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 4.7041e-04 - mae: 0.0171 - val_loss: 0.0055 - val_mae: 0.0613
# Epoch 17/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 6.2889e-04 - mae: 0.0201 - val_loss: 0.0058 - val_mae: 0.0633
# Epoch 18/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 5.7581e-04 - mae: 0.0188 - val_loss: 0.0064 - val_mae: 0.0679
# Epoch 19/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 61ms/step - loss: 6.8974e-04 - mae: 0.0206 - val_loss: 0.0074 - val_mae: 0.0735
# Epoch 20/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 5.3932e-04 - mae: 0.0175 - val_loss: 0.0067 - val_mae: 0.0690
# Epoch 21/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 4.3649e-04 - mae: 0.0167 - val_loss: 0.0061 - val_mae: 0.0660
# Epoch 22/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step - loss: 3.9384e-04 - mae: 0.0158 - val_loss: 0.0062 - val_mae: 0.0657
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step
# 📊 Fine-Tuned GRU Performance — RMSE: 8.3362, MAE: 6.8681, R²: 0.6961

# %%
# ✅ Match index to real validation dates
val_dates = stock_df.index[-len(y_val_inv):]

# ✅ Plot actual vs predicted
plt.figure(figsize=(12, 6))
plt.plot(val_dates, y_val_inv, label='True', color='blue')
plt.plot(val_dates, fine_tuned_gru_y_pred_inv, label='Predicted (Fine-Tuned GRU)', color='orange', linestyle='--')
plt.title("Fine-Tuned GRU Forecast vs True")
plt.xlabel("Date")
plt.ylabel("Close Price")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.gcf().autofmt_xdate()
plt.show()

# %% [markdown]
# # SHAP Analysis of Updated GRU

# %%
# 1. Select sample sequences for explanation
X_val_sample = X_val[:10]  # Select 10 samples for SHAP
background_sample = X_train[np.random.choice(X_train.shape[0], 50, replace=False)]  # 50 samples for background

# 2. Flatten the sequences for SHAP input (samples, timesteps * features)
X_val_flat = X_val_sample.reshape((X_val_sample.shape[0], -1))
background_flat = background_sample.reshape((background_sample.shape[0], -1))

# 3. Define prediction function compatible with KernelExplainer
#    Reshapes the flat input back to 3D format expected by the model
def predict_flat(X_flat):
    X_reshaped = X_flat.reshape(-1, X.shape[1], X.shape[2])
    return fine_tuned_gru.predict(X_reshaped)

# 4. Initialize SHAP KernelExplainer with the prediction function
explainer = shap.KernelExplainer(predict_flat, background_flat)

# 5. Compute SHAP values for the selected validation samples
shap_values_fine_gru = explainer.shap_values(X_val_flat, nsamples=200)

# 6. Squeeze to remove any singleton dimensions and reshape to (samples, timesteps, features)
shap_arr = np.squeeze(np.array(shap_values_fine_gru))
shap_reshaped = shap_arr.reshape(X_val_sample.shape[0], X.shape[1], X.shape[2])

# 7. Aggregate SHAP values: mean over time, then mean over samples
mean_shap_timestep = np.mean(np.abs(shap_reshaped), axis=1)
mean_feature_importance = np.mean(mean_shap_timestep, axis=0)

# 8. Plot Feature Importance
plt.figure(figsize=(10, 6))
plt.barh(feature_cols, mean_feature_importance, color='orange')
plt.xlabel("Mean SHAP Value")
plt.title("Fine-Tuned GRU - Feature Importance (Kernel SHAP)")
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
#   0%|          | 0/10 [00:00<?, ?it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step

# %%
top_k = 5
top_indices = np.argsort(mean_feature_importance)[-top_k:]

plt.barh(np.array(feature_cols)[top_indices], mean_feature_importance[top_indices], color='orange')
plt.xlabel("Mean SHAP Value")
plt.title("Top 5 Important Features (Fine Tuned GRU SHAP)")
plt.tight_layout()
plt.grid(True)
plt.show()

# %% [markdown]
# ### 4-3. Build CNN

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Dropout, Flatten, Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping

# 7. Build CNN model
cnn_model = Sequential()
cnn_model.add(Conv1D(filters=64, kernel_size=3, activation='relu', input_shape=(X.shape[1], X.shape[2])))
cnn_model.add(MaxPooling1D(pool_size=2))
cnn_model.add(Dropout(0.3))
cnn_model.add(Conv1D(filters=32, kernel_size=3, activation='relu'))
cnn_model.add(MaxPooling1D(pool_size=2))
cnn_model.add(Flatten())
cnn_model.add(Dense(64, activation='relu'))
cnn_model.add(Dense(1))

cnn_model.compile(optimizer=Adam(learning_rate=0.0005), loss='mse', metrics=['mae'])

# 8. Train
early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
cnn_history = cnn_model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=100,
    batch_size=32,
    callbacks=[early_stop],
    verbose=1
)

# 9. Predict and inverse transform
cnn_y_pred = cnn_model.predict(X_val)
cnn_y_val_inv = y_scaler.inverse_transform(y_val)
cnn_y_pred_inv = y_scaler.inverse_transform(cnn_y_pred)

# 10. Evaluation
cnn_rmse = np.sqrt(mean_squared_error(cnn_y_val_inv, cnn_y_pred_inv))
cnn_mae = mean_absolute_error(cnn_y_val_inv, cnn_y_pred_inv)
cnn_r2 = r2_score(cnn_y_val_inv, cnn_y_pred_inv)

print(f"✅ CNN Performance — RMSE: {cnn_rmse:.4f}, MAE: {cnn_mae:.4f}, R²: {cnn_r2:.4f}")

# 11. Plot results
plt.figure(figsize=(10, 5))
plt.plot(val_dates, cnn_y_val_inv, label='True')
plt.plot(val_dates, cnn_y_pred_inv, label='Predicted')
plt.legend()
plt.title("CNN Forecast vs True")
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Epoch 1/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 0.0380 - mae: 0.1553 - val_loss: 0.0385 - val_mae: 0.1846
# Epoch 2/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0072 - mae: 0.0661 - val_loss: 0.0526 - val_mae: 0.2186
# Epoch 3/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0041 - mae: 0.0506 - val_loss: 0.0538 - val_mae: 0.2226
# Epoch 4/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0030 - mae: 0.0429 - val_loss: 0.0480 - val_mae: 0.2094
# Epoch 5/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0025 - mae: 0.0405 - val_loss: 0.0376 - val_mae: 0.1847
# Epoch 6/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0022 - mae: 0.0363 - val_loss: 0.0382 - val_mae: 0.1868
# Epoch 7/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0017 - mae: 0.0321 - val_loss: 0.0378 - val_mae: 0.1863
# Epoch 8/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0016 - mae: 0.0311 - val_loss: 0.0342 - val_mae: 0.1782
# Epoch 9/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0015 - mae: 0.0293 - val_loss: 0.0302 - val_mae: 0.1671
# Epoch 10/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0015 - mae: 0.0306 - val_loss: 0.0273 - val_mae: 0.1585
# Epoch 11/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0012 - mae: 0.0265 - val_loss: 0.0302 - val_mae: 0.1668
# Epoch 12/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0012 - mae: 0.0270 - val_loss: 0.0303 - val_mae: 0.1675
# Epoch 13/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0012 - mae: 0.0269 - val_loss: 0.0279 - val_mae: 0.1601
# Epoch 14/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0011 - mae: 0.0258 - val_loss: 0.0231 - val_mae: 0.1451
# Epoch 15/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0011 - mae: 0.0251 - val_loss: 0.0278 - val_mae: 0.1600
# Epoch 16/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.3155e-04 - mae: 0.0239 - val_loss: 0.0270 - val_mae: 0.1574
# Epoch 17/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0011 - mae: 0.0250 - val_loss: 0.0248 - val_mae: 0.1505
# Epoch 18/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0010 - mae: 0.0247 - val_loss: 0.0334 - val_mae: 0.1758
# Epoch 19/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.9286e-04 - mae: 0.0235 - val_loss: 0.0320 - val_mae: 0.1721
# Epoch 20/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.9889e-04 - mae: 0.0236 - val_loss: 0.0311 - val_mae: 0.1693
# Epoch 21/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.5831e-04 - mae: 0.0243 - val_loss: 0.0277 - val_mae: 0.1591
# Epoch 22/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 9.5618e-04 - mae: 0.0240 - val_loss: 0.0355 - val_mae: 0.1813
# Epoch 23/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.7729e-04 - mae: 0.0232 - val_loss: 0.0350 - val_mae: 0.1800
# Epoch 24/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.3555e-04 - mae: 0.0228 - val_loss: 0.0366 - val_mae: 0.1843
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# ✅ CNN Performance — RMSE: 17.2998, MAE: 16.5153, R²: -0.3086

# %%
# 1. Sample sequences for SHAP explanation (10 samples for demo)
X_val_sample = X_val[:10]

# 2. Prepare background sample (random from training data)
background_sample = X_train[np.random.choice(X_train.shape[0], 50, replace=False)]

# 3. Flatten sequences for KernelExplainer (samples, timesteps * features)
X_val_flat = X_val_sample.reshape((X_val_sample.shape[0], -1))
background_flat = background_sample.reshape((background_sample.shape[0], -1))

# 4. Define prediction function that reshapes back for the model
def predict_flat(X_flat):
    X_reshaped = X_flat.reshape(-1, X.shape[1], X.shape[2])
    return cnn_model.predict(X_reshaped)

# 5. Initialize KernelExplainer
explainer = shap.KernelExplainer(predict_flat, background_flat)

# 6. Compute SHAP values (this can take a few minutes)
shap_values_cnn = explainer.shap_values(X_val_flat, nsamples=200)

# 7. Reshape SHAP values back to (samples, timesteps, features)
shap_arr = np.array(shap_values_cnn).squeeze()  # Shape: (10, timesteps * features)
shap_arr = shap_arr.reshape(X_val_sample.shape[0], X_val_sample.shape[1], X_val_sample.shape[2])

# 8. Aggregate SHAP values
# Mean over time (timesteps), then mean over samples to get (features,)
mean_shap_time = np.mean(np.abs(shap_arr), axis=1)
mean_feature_importance = np.mean(mean_shap_time, axis=0)

# 9. Plot Feature Importance
plt.figure(figsize=(12, 6))
plt.barh(feature_cols, mean_feature_importance, color='orange')
plt.xlabel("Mean SHAP Value")
plt.title("CNN - Feature Importance (SHAP)")
plt.tight_layout()
plt.grid(True)
plt.show()
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
#   0%|          | 0/10 [00:00<?, ?it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step

# %%
top_k = 5
top_indices = np.argsort(mean_feature_importance)[-top_k:]

plt.barh(np.array(feature_cols)[top_indices], mean_feature_importance[top_indices], color='orange')
plt.xlabel("Mean SHAP Value")
plt.title("Top 5 Important Features (CNN SHAP)")
plt.tight_layout()
plt.grid(True)
plt.show()

# %% [markdown]
# ### 4-4. CNN hybird Model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, GRU, Dropout, Dense, Flatten
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping

# 7. Build CNN–GRU Hybrid Model
hybrid_model = Sequential()
hybrid_model.add(Conv1D(filters=64, kernel_size=3, activation='relu', input_shape=(X.shape[1], X.shape[2])))
hybrid_model.add(MaxPooling1D(pool_size=2))
hybrid_model.add(Dropout(0.3))
hybrid_model.add(GRU(64, return_sequences=True))
hybrid_model.add(GRU(32))
hybrid_model.add(Dense(32, activation='relu'))
hybrid_model.add(Dense(1))

hybrid_model.compile(optimizer=Adam(learning_rate=0.0005), loss='mse', metrics=['mae'])

# 8. Train
early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
hybrid_history = hybrid_model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=100,
    batch_size=32,
    callbacks=[early_stop],
    verbose=1
)

# 9. Predict and inverse transform
hybrid_y_pred = hybrid_model.predict(X_val)
hybrid_y_val_inv = y_scaler.inverse_transform(y_val)
hybrid_y_pred_inv = y_scaler.inverse_transform(hybrid_y_pred)

# 10. Evaluation
hybrid_rmse = np.sqrt(mean_squared_error(hybrid_y_val_inv, hybrid_y_pred_inv))
hybrid_mae = mean_absolute_error(hybrid_y_val_inv, hybrid_y_pred_inv)
hybrid_r2 = r2_score(hybrid_y_val_inv, hybrid_y_pred_inv)

print(f"✅ Hybrid CNN–GRU Performance — RMSE: {hybrid_rmse:.4f}, MAE: {hybrid_mae:.4f}, R²: {hybrid_r2:.4f}")

# 11. Plot results
plt.figure(figsize=(10, 5))
plt.plot(val_dates, hybrid_y_val_inv, label='True')
plt.plot(val_dates, hybrid_y_pred_inv, label='Predicted')
plt.legend()
plt.title("CNN–GRU Forecast vs True")
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Epoch 1/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 6s 48ms/step - loss: 0.0201 - mae: 0.1080 - val_loss: 0.0167 - val_mae: 0.1155
# Epoch 2/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0023 - mae: 0.0384 - val_loss: 0.0162 - val_mae: 0.1128
# Epoch 3/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0016 - mae: 0.0312 - val_loss: 0.0163 - val_mae: 0.1112
# Epoch 4/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0012 - mae: 0.0276 - val_loss: 0.0147 - val_mae: 0.1034
# Epoch 5/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0011 - mae: 0.0265 - val_loss: 0.0203 - val_mae: 0.1247
# Epoch 6/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0010 - mae: 0.0252 - val_loss: 0.0203 - val_mae: 0.1237
# Epoch 7/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 9.7780e-04 - mae: 0.0245 - val_loss: 0.0214 - val_mae: 0.1280
# Epoch 8/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 9.2665e-04 - mae: 0.0237 - val_loss: 0.0279 - val_mae: 0.1490
# Epoch 9/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 8.0202e-04 - mae: 0.0225 - val_loss: 0.0272 - val_mae: 0.1470
# Epoch 10/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 8.0622e-04 - mae: 0.0224 - val_loss: 0.0238 - val_mae: 0.1347
# Epoch 11/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 7.1807e-04 - mae: 0.0210 - val_loss: 0.0274 - val_mae: 0.1459
# Epoch 12/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 8.0662e-04 - mae: 0.0229 - val_loss: 0.0373 - val_mae: 0.1741
# Epoch 13/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 7.4518e-04 - mae: 0.0216 - val_loss: 0.0312 - val_mae: 0.1566
# Epoch 14/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 6.8818e-04 - mae: 0.0206 - val_loss: 0.0355 - val_mae: 0.1675
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step
# ✅ Hybrid CNN–GRU Performance — RMSE: 13.7765, MAE: 11.7708, R²: 0.1701

# %%
# 1. Sample sequences for SHAP explanation (10 samples for demo)
X_val_sample = X_val[:10]

# 2. Prepare background sample (random from training data)
background_sample = X_train[np.random.choice(X_train.shape[0], 50, replace=False)]

# 3. Flatten sequences for KernelExplainer (samples, timesteps * features)
X_val_flat = X_val_sample.reshape((X_val_sample.shape[0], -1))
background_flat = background_sample.reshape((background_sample.shape[0], -1))

# 4. Define prediction function that reshapes back for the model
def predict_flat(X_flat):
    X_reshaped = X_flat.reshape(-1, X.shape[1], X.shape[2])
    return hybrid_model.predict(X_reshaped)

# 5. Initialize KernelExplainer
explainer = shap.KernelExplainer(predict_flat, background_flat)

# 6. Compute SHAP values (this can take a few minutes)
shap_values_hybrid = explainer.shap_values(X_val_flat, nsamples=200)

# 7. Reshape SHAP values back to (samples, timesteps, features)
shap_arr = np.array(shap_values_hybrid).squeeze()  # Shape: (10, timesteps * features)
shap_arr = shap_arr.reshape(X_val_sample.shape[0], X_val_sample.shape[1], X_val_sample.shape[2])

# 8. Aggregate SHAP values
# Mean over time (timesteps), then mean over samples to get (features,)
mean_shap_time = np.mean(np.abs(shap_arr), axis=1)
mean_feature_importance = np.mean(mean_shap_time, axis=0)

# 9. Plot Feature Importance
plt.figure(figsize=(12, 6))
plt.barh(feature_cols, mean_feature_importance, color='orange')
plt.xlabel("Mean SHAP Value")
plt.title("Hybrid CNN-GRU - Feature Importance (SHAP)")
plt.tight_layout()
plt.grid(True)
plt.show()
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
#   0%|          | 0/10 [00:00<?, ?it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step

# %%
top_k = 5
top_indices = np.argsort(mean_feature_importance)[-top_k:]

plt.barh(np.array(feature_cols)[top_indices], mean_feature_importance[top_indices], color='orange')
plt.xlabel("Mean SHAP Value")
plt.title("Top 5 Important Features (CNN–GRU SHAP)")
plt.tight_layout()
plt.grid(True)
plt.show()

# %%
for layer in hybrid_model.layers:
    print(layer.name)
# Out:
# conv1d_2
# max_pooling1d_2
# dropout_3
# gru_3
# gru_4
# dense_10
# dense_11

# %% [markdown]
# # Build Grad-CAM

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# Functional Input
input_tensor = tf.keras.Input(shape=X_val.shape[1:])

# Pass input through the model and automatically capture the first Conv1D layer's output
x = input_tensor
target_conv_output = None

for layer in hybrid_model.layers:
    x = layer(x)
    if isinstance(layer, tf.keras.layers.Conv1D) and target_conv_output is None:
        target_conv_output = x  # Capture the first Conv1D output

# Build the Grad-CAM model
grad_model = tf.keras.models.Model(inputs=input_tensor, outputs=[target_conv_output, x])

# %%
# 1. Try middle or volatile part of validation set
input_sequence = X_val[[len(X_val)//2]]

# 2. Compute gradients w.r.t convolution outputs
with tf.GradientTape() as tape:
    conv_outputs, predictions = grad_model(input_sequence)
    loss = predictions[:, 0]  # focus on output neuron

# 3. Get gradients of conv outputs
grads = tape.gradient(loss, conv_outputs)

# 4. Global average pooling of gradients
pooled_grads = tf.reduce_mean(grads, axis=(1, 2))

# Check if grads are meaningful
print("Gradient mean:", pooled_grads.numpy())

# 5. Weight conv outputs by gradients
conv_outputs = conv_outputs[0]  # remove batch dimension
heatmap = tf.reduce_sum(conv_outputs * pooled_grads[:, tf.newaxis], axis=-1)

# 6. Apply ReLU and normalize
heatmap = tf.nn.relu(heatmap)
max_val = tf.reduce_max(heatmap)
if max_val > 0:
    heatmap = heatmap / max_val
else:
    print("Heatmap has no variation (max=0)")
    heatmap = tf.zeros_like(heatmap)

# ✅ Ensure time index is datetime and aligns with y_val
time_index = val_dates[-len(y_val_inv):]  # should match y_val_inv length
if not np.issubdtype(time_index.dtype, np.datetime64):
    time_index = pd.to_datetime(time_index)

# 7. Plot Grad-CAM overlay
plt.figure(figsize=(12, 6))
plt.plot(time_index, y_val_inv, label='True Close Price', color='blue')
plt.title("Grad-CAM Visualization - CNN-GRU Stock Forecasting")
plt.xlabel("Date")
plt.ylabel("Close Price")

# Use same aligned time_index for heatmap extent
plt.imshow(
    heatmap.numpy()[np.newaxis, :],  # (1, timesteps)
    aspect='auto',
    cmap='jet',
    extent=[time_index[0], time_index[-1], plt.ylim()[0], plt.ylim()[1]],
    alpha=0.4
)

plt.colorbar(label='Feature Importance (Grad-CAM)')
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# Gradient mean: [-0.00031808]
# Heatmap has no variation (max=0)

# %% [markdown]
# ### 4-5. Build Multivariate Linear Regression (Flatten based) - to directly compare with other models
#
# - Apply Linear Regression using the same `X_train` and `X_val` data as other models, after flattening the 3D input.

# %%
from sklearn.linear_model import LinearRegression

# %%
# Flatten 3D input into 2D: (samples, timesteps * features)
X_train_flat = X_train.reshape(X_train.shape[0], -1)
X_val_flat = X_val.reshape(X_val.shape[0], -1)

# Initialize and train Linear Regression model
lr_model_flat = LinearRegression()
lr_model_flat.fit(X_train_flat, y_train)

# Predict and inverse transform
lr_y_pred_flat = lr_model_flat.predict(X_val_flat)
lr_y_pred_flat_inv = y_scaler.inverse_transform(lr_y_pred_flat.reshape(-1, 1))
lr_y_val_inv = y_scaler.inverse_transform(y_val)

# Evaluation
lr_rmse = np.sqrt(mean_squared_error(lr_y_val_inv, lr_y_pred_flat_inv))
lr_mae = mean_absolute_error(lr_y_val_inv, lr_y_pred_flat_inv)
lr_r2 = r2_score(lr_y_val_inv, lr_y_pred_flat_inv)

print("📊 Linear Regression (flattened GRU input) Performance:")
print(f"RMSE: {lr_rmse:.4f}, MAE: {lr_mae:.4f}, R²: {lr_r2:.4f}")

# Plot
plt.figure(figsize=(10, 5))
plt.plot(val_dates, lr_y_val_inv, label='True')
plt.plot(val_dates, lr_y_pred_flat_inv, label='Predicted (LR)', linestyle='--')
plt.legend()
plt.title("Linear Regression Forecast vs True (Flattened Input)")
plt.tight_layout()
plt.grid(True)
plt.show()
# Out:
# 📊 Linear Regression (flattened GRU input) Performance:
# RMSE: 1.8993, MAE: 1.4663, R²: 0.9842

# %%
# Step 2: Generate flattened feature names preserving time info
flat_feature_names = []
for t in range(X.shape[1]):
    for f in feature_cols:
        flat_feature_names.append(f"{f}_t{t+1}")  # e.g., "SMA_20_t1"

# Step 4: Run SHAP Explainer
X_train_df = pd.DataFrame(X_train_flat, columns=flat_feature_names)
X_val_df = pd.DataFrame(X_val_flat, columns=flat_feature_names)

explainer = shap.Explainer(lr_model_flat, X_train_df)
shap_values = explainer(X_val_df)

# Step 5: Convert SHAP values to DataFrame and group by base feature name (removing _tN)
shap_df = pd.DataFrame(np.abs(shap_values.values), columns=flat_feature_names)

# Remove time index and group
base_feature_names = [name.split("_t")[0] for name in shap_df.columns]
shap_df.columns = base_feature_names

# Now aggregate: mean across columns with the same base feature name
mean_shap_per_feature = shap_df.groupby(shap_df.columns, axis=1).mean().mean(axis=0)

# Step 6: Plot
plt.figure(figsize=(10, 6))
mean_shap_per_feature.sort_values().plot(kind='barh', color='orange')
plt.xlabel("Mean SHAP Value")
plt.title("SHAP Feature Importance – Linear Regression (No Time Info, Preserved Names)")
plt.tight_layout()
plt.grid(True)
plt.show()

# %% [markdown]
# ### 4-6. Build Multivariate Linear Regression (Custom Optimized)
#
# - Build a separate Linear Regression model using handcrafted lag and technical indicator feature from `stock_df` to predict the next day's closing price.

# %%
# Define features and target
custom_lr_features = [
     'Volume', 'Open', 'High', 'Low', 'RSI_14', 'MACD', 'MACD_signal',
            'SMA_5', 'SMA_20', 'EMA_20', 'norm_price', 'price_lag1', 'price_lag2',
            'return_lag1', 'volatility_5', 'volatility_20', 'vol_ratio'
]

# Define target: 1-day ahead closing price
stock_df['target_next_day'] = stock_df['Close'].shift(-1)

# Drop NA due to shift
custom_df = stock_df[custom_lr_features + ['target_next_day']].dropna().copy()

# Split into train/test
split_idx = int(len(custom_df) * 0.8)
X_custom_train = custom_df.iloc[:split_idx][custom_lr_features]
X_custom_val = custom_df.iloc[split_idx:][custom_lr_features]
y_custom_train = custom_df.iloc[:split_idx]['target_next_day']
y_custom_val = custom_df.iloc[split_idx:]['target_next_day']

val_dates_custom = y_custom_val.index  

# Train Linear Regression
lr_model_custom = LinearRegression()
lr_model_custom.fit(X_custom_train, y_custom_train)

# Predict and evaluate
y_custom_pred = lr_model_custom.predict(X_custom_val)

custom_rmse = np.sqrt(mean_squared_error(y_custom_val, y_custom_pred))
custom_mae = mean_absolute_error(y_custom_val, y_custom_pred)
custom_r2 = r2_score(y_custom_val, y_custom_pred)

print("📊 Linear Regression (custom features) Performance:")
print(f"RMSE: {custom_rmse:.4f}, MAE: {custom_mae:.4f}, R²: {custom_r2:.4f}")

# Plot
plt.figure(figsize=(10, 5))
plt.plot(val_dates_custom, y_custom_val.values, label='True')
plt.plot(val_dates_custom, y_custom_pred, label='Predicted (Custom LR)', linestyle='--')
plt.legend()
plt.title("Linear Regression Forecast vs True (Custom Features)")
plt.tight_layout()
plt.grid(True)
plt.show()
# Out:
# 📊 Linear Regression (custom features) Performance:
# RMSE: 1.6774, MAE: 1.3098, R²: 0.9879

# %%
explainer = shap.Explainer(lr_model_custom, X_custom_train)
shap_values_custom = explainer(X_custom_val)

# Only show the SHAP summary bar plot (preferred)
shap.plots.bar(shap_values_custom, max_display=15)

# Summary plot (beeswarm plot)
shap.summary_plot(shap_values_custom, X_custom_val)

# %% [markdown]
# # 5. Financial Evaluation - Sharpe Ratio & Cumulative Returns

# %%
import matplotlib.dates as mdates
# -------------------------------------------------------------------------------
# Helper functions for financial evaluation
def compute_returns(prices):
    """Calculate daily returns from price series."""
    return np.diff(prices, axis=0) / prices[:-1]

def compute_cumulative_returns(returns):
    """Calculate cumulative returns from daily returns."""
    return np.cumprod(1 + returns)

def compute_sharpe_ratio(returns, risk_free_rate=0.0):
    """Compute Sharpe Ratio assuming a constant risk-free rate."""
    excess_returns = returns - risk_free_rate
    return np.mean(excess_returns) / np.std(excess_returns)

# -------------------------------------------------------------------------------
# ✅ Dictionary of predictions from each model (make sure all are 1D np.arrays)
models = {
    "GRU": gru_y_pred.flatten(),
    "Fine-Tuned GRU": fine_tuned_gru_y_pred.flatten(),
    "CNN": cnn_y_pred.flatten(),
    "CNN–GRU Hybrid": hybrid_y_pred.flatten(),
    "Linear Regression (Flat)": lr_y_pred_flat.flatten(),
    "Linear Regression (Custom)": y_custom_pred.flatten()
}

# ✅ Inverse transform true y_val
y_val_inverse = y_scaler.inverse_transform(y_val)

# ✅ True values (inverse-transformed y_val or y_custom_val depending on D=1)
true_prices = y_val_inverse.flatten()  # Should match GRU/CNN/etc. val size

# ✅ Corresponding dates (you can also pass separate indices per model if needed)
val_dates_all = val_dates[1:]  # since returns lose the first value (diff)

# -------------------------------------------------------------------------------
# ✅ Store evaluation results
results = []

# ✅ Plot cumulative returns for each model
plt.figure(figsize=(12, 6))

for model_name, preds in models.items():
    returns = compute_returns(preds)
    cum_returns = compute_cumulative_returns(returns)
    sharpe = compute_sharpe_ratio(returns)

    results.append({
        "Model": model_name,
        "Sharpe Ratio": sharpe,
        "Final Cumulative Return": cum_returns[-1]
    })

    aligned_dates = val_dates[-len(preds):][1:]
    cum_returns = cum_returns[:len(aligned_dates)]  

    plt.plot(aligned_dates, cum_returns, label=model_name)

# Format x-axis as dates
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))
plt.gca().xaxis.set_major_locator(mdates.MonthLocator())
plt.gcf().autofmt_xdate()

plt.title("Cumulative Returns by Model")
plt.xlabel("Date")
plt.ylabel("Cumulative Return")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.gcf().autofmt_xdate()
plt.show()

# Print summary table
summary_df = pd.DataFrame(results).sort_values(by="Sharpe Ratio", ascending=False)
print("📊 Sharpe Ratio & Cumulative Returns Summary")
display(summary_df)
# Out:
# 📊 Sharpe Ratio & Cumulative Returns Summary
#                         Model  Sharpe Ratio  Final Cumulative Return
# 2                         CNN      0.317071                 1.798906
# 1              Fine-Tuned GRU      0.310187                 1.550963
# 3              CNN–GRU Hybrid      0.267927                 1.439344
# 0                         GRU      0.158329                 1.354728
# 5  Linear Regression (Custom)      0.140455                 1.425631
# 4    Linear Regression (Flat)      0.095531                 1.670758

# %%
full_results = [
    {
        "Model": "Linear Regression (Flat)",
        "R²": lr_r2,
        "RMSE": lr_rmse,
        "MAE": lr_mae,
        "Sharpe Ratio": next(item["Sharpe Ratio"] for item in results if item["Model"] == "Linear Regression (Flat)"),
        "Cumulative Return": next(item["Final Cumulative Return"] for item in results if item["Model"] == "Linear Regression (Flat)")
    },
    {
        "Model": "Linear Regression (Custom)",
        "R²": custom_r2,
        "RMSE": custom_rmse,
        "MAE": custom_mae,
        "Sharpe Ratio": next(item["Sharpe Ratio"] for item in results if item["Model"] == "Linear Regression (Custom)"),
        "Cumulative Return": next(item["Final Cumulative Return"] for item in results if item["Model"] == "Linear Regression (Custom)")
    },
    {
        "Model": "GRU",
        "R²": gru_r2,
        "RMSE": gru_rmse,
        "MAE": gru_mae,
        "Sharpe Ratio": next(item["Sharpe Ratio"] for item in results if item["Model"] == "GRU"),
        "Cumulative Return": next(item["Final Cumulative Return"] for item in results if item["Model"] == "GRU")
    },
    {
        "Model": "Fine-Tuned GRU",
        "R²": r2,
        "RMSE": rmse,
        "MAE": mae,
        "Sharpe Ratio": next(item["Sharpe Ratio"] for item in results if item["Model"] == "Fine-Tuned GRU"),
        "Cumulative Return": next(item["Final Cumulative Return"] for item in results if item["Model"] == "Fine-Tuned GRU")
    },
    {
        "Model": "CNN",
        "R²": cnn_r2,
        "RMSE": cnn_rmse,
        "MAE": cnn_mae,
        "Sharpe Ratio": next(item["Sharpe Ratio"] for item in results if item["Model"] == "CNN"),
        "Cumulative Return": next(item["Final Cumulative Return"] for item in results if item["Model"] == "CNN")
    },
    {
        "Model": "CNN–GRU Hybrid",
        "R²": hybrid_r2,
        "RMSE": hybrid_rmse,
        "MAE": hybrid_mae,
        "Sharpe Ratio": next(item["Sharpe Ratio"] for item in results if item["Model"] == "CNN–GRU Hybrid"),
        "Cumulative Return": next(item["Final Cumulative Return"] for item in results if item["Model"] == "CNN–GRU Hybrid")
    }
]

summary_df = pd.DataFrame(full_results)
summary_df = summary_df.round(4) 

from IPython.display import display, Markdown

display(Markdown(f"### 📈 Model Performance Summary for **{ticker}**"))
display(summary_df)
# Out:
# ### 📈 Model Performance Summary for **CBA**
#                         Model      R²     RMSE      MAE  Sharpe Ratio  \
# 0    Linear Regression (Flat)  0.9842   1.8993   1.4663        0.0955
# 1  Linear Regression (Custom)  0.9879   1.6774   1.3098        0.1405
# 2                         GRU  0.7196   8.0084   7.3887        0.1583
# 3              Fine-Tuned GRU  0.6961   8.3362   6.8681        0.3102
# 4                         CNN -0.3086  17.2998  16.5153        0.3171
# 5              CNN–GRU Hybrid  0.1701  13.7765  11.7708        0.2679
#
#    Cumulative Return
# 0             1.6708
# 1             1.4256
# 2             1.3547
# 3             1.5510
# 4             1.7989
# 5             1.4393

# %% [markdown]
# - **R² (R-squared)**:
# Measures prediction accuracy.
# → The closer to **1**, the better the model fits the data.
#
# - **RMSE / MAE**:
# Indicators of prediction error.
# → **Lower** values indicate better performance.
#
# - **Sharpe Ratio**:
# Measures risk-adjusted return.
# → **Higher** is better. A **negative** Sharpe Ratio indicates poor risk-return tradeoff.
#
# - **Cumulative Return**:
# Total return over the test period.
# → **Higher** values indicate better long-term performance.

# %%
# Set plotting style
sns.set(style="darkgrid")
display(Markdown(f"### 📈 Monthly Trend Analysis for **{ticker}**"))

# Monthly trend and volatility
monthly_price = stock_df['Close'].resample('M').mean()
monthly_return = monthly_price.pct_change()
monthly_volatility = stock_df['Close'].pct_change().resample('M').std()

# Plot monthly price trend
plt.figure(figsize=(12, 4))
monthly_price.plot()
plt.title("Monthly Average Price")
plt.xlabel("Date")
plt.ylabel("Average Monthly Price")
plt.tight_layout()
plt.show()

# Plot monthly return
plt.figure(figsize=(12, 4))
monthly_return.plot(marker='o', linestyle='-')
plt.title("Monthly Returns")
plt.xlabel("Date")
plt.ylabel("Return")
plt.axhline(0, color='gray', linestyle='--')
plt.tight_layout()
plt.show()

# Plot monthly volatility
plt.figure(figsize=(12, 4))
monthly_volatility.plot(marker='o', color='orange')
plt.title("Monthly Volatility (Standard Deviation of Daily Returns)")
plt.xlabel("Date")
plt.ylabel("Volatility")
plt.tight_layout()
plt.show()
# Out:
# ### 📈 Monthly Trend Analysis for **CBA**

# %% [markdown]
# CBA is less likely to show sudden spikes or drops, but rather undergoes **structural shifts over time**. This justifies a monthly resampling approach to better capture its trend dynamics.
#
# ### 📈 Monthly Average Price
# - CBA demonstrates a **steady upward trend**, making it well-suited for long-term holding strategies.
# - Especially since **2023**, the growth has been more pronounced, reflecting both **stability and strong long-term growth potential**.
#
# ### 📉 Monthly Returns
# - Returns are generally in the **positive range**, with occasional negative spikes.
# - Most significant negative returns were concentrated around **early 2020 during the pandemic, while recent returns have been more stable**.
#
# ### 📉 Monthly Volatility
# - Volatility was **very high in 2020**, but has **declined significantly over time**.
# - In recent years, volatility has remained at **consistently low levels**.
#
# This supports the interpretation that **simple models like Linear Regression** are particularly effective for forecasting CBA due to its stability.
#
# ### ✅ Conclusion
# This monthly-level analysis reinforces CBA's profile as a **stable, trend-driven asset**.
# It provides **strong supporting evidence** for recommending CBA and Linear Regression to **conservative investors**, who prioritize **predictability and low risk** in their investment strategies.

# %%
from sklearn.inspection import PartialDependenceDisplay

# ✅ PDP: Top 3 important features from SHAP summary
top_features = ['SMA_20', 'Low', 'High']

# ✅ Plot Partial Dependence
fig, ax = plt.subplots(ncols=len(top_features), figsize=(15, 4))
PartialDependenceDisplay.from_estimator(
    lr_model_custom,
    X_custom_val,
    features=top_features,
    ax=ax
)
display(Markdown(f"### 📈 Causal Approximation for **{ticker}**"))
plt.suptitle("Partial Dependence Plots for Top SHAP Features (Causal Approximation)", fontsize=14)
plt.tight_layout()
plt.show()
# Out:
# ### 📈 Causal Approximation for **CBA**

# %% [markdown]
# ### **Causal Learning**: Interpreting Causal Relationships
# While CBA shows strong predictive accuracy, it may lack persuasive power in terms of model interpretability.
#
# By combining SHAP values with Partial Dependence Plots (PDP) or even causal inference frameworks (like Causal Graphs), we can explain:
#
# This is especially useful when communicating with conservative investors who value explainability over model complexity.
#
# - Our PDP plots show that features like SMA_20 (20-day Simple Moving Average), Low, and High prices have a positive causal effect on predicted closing prices.
#
# - In each plot:
#
#     - As the X-axis increases (i.e., the feature value increases),
#
#     - The predicted output also consistently increases.

# %% [markdown]
# ### DoWhy Causal Analysis

# %%
#!pip install dowhy

# %%
from dowhy import CausalModel

# Step 1: Prepare DataFrame
causal_df = custom_df[['target_next_day', 'SMA_20', 'Low', 'High']].dropna().copy()
causal_df = causal_df.rename(columns={'target_next_day': 'Close'})  # rename target for DoWhy

# Step 2: Define causal model
model = CausalModel(
    data=causal_df,
    treatment='SMA_20',
    outcome='Close',
    common_causes=['Low', 'High']
)

# Step 3: Identify causal effect
identified_estimand = model.identify_effect()
print("Identified estimand:")
print(identified_estimand)

# Step 4: Estimate effect using linear regression
estimate = model.estimate_effect(
    identified_estimand,
    method_name="backdoor.linear_regression"
)
print("Estimated effect:")
print(estimate)

# Step 5: Refute estimate using placebo test
refutation = model.refute_estimate(
    identified_estimand,
    estimate,
    method_name="placebo_treatment_refuter"
)
print("Refutation result:")
print(refutation)
# Out:
# Identified estimand:
# Estimand type: EstimandType.NONPARAMETRIC_ATE
#
# ### Estimand : 1
# Estimand name: backdoor
# Estimand expression:
#    d
# ────────(E[Close|High,Low])
# d[SMA₂₀]
# Estimand assumption 1, Unconfoundedness: If U→{SMA_20} and U→Close then P(Close|SMA_20,High,Low,U) = P(Close|SMA_20,High,Low)
#
# ### Estimand : 2
# Estimand name: iv
# No such variable(s) found!
#
# ### Estimand : 3
# Estimand name: frontdoor
# No such variable(s) found!
#
# Estimated effect:
# *** Causal Estimate ***
#
# ## Identified estimand
# Estimand type: EstimandType.NONPARAMETRIC_ATE
#
# ### Estimand : 1
# Estimand name: backdoor
# Estimand expression:
#    d
# ────────(E[Close|High,Low])
# d[SMA₂₀]
# Estimand assumption 1, Unconfoundedness: If U→{SMA_20} and U→Close then P(Close|SMA_20,High,Low,U) = P(Close|SMA_20,High,Low)
#
# ## Realized estimand
# b: Close~SMA_20+High+Low
# Target units: ate
#
# ## Estimate
# Mean value: -0.017056846274257964
#
# Refutation result:
# Refute: Use a Placebo Treatment
# Estimated effect:-0.017056846274257964
# New effect:0.0
# p value:1.0

# %%
from dowhy import CausalModel

# Prepare Dataframe
causal_df = custom_df[['SMA_20', 'Low', 'High', 'target_next_day']].dropna()
causal_df = causal_df.rename(columns={'target_next_day': 'Close'})

# Step 2: Define causal model iteratively
def run_causal_analysis(treatment, common_causes):
    model = CausalModel(
        data=causal_df,
        treatment=treatment,
        outcome='Close',
        common_causes=common_causes
    )
    identified_estimand = model.identify_effect() # Step 3: Identify causal effect
    estimate = model.estimate_effect( # Step 4: Estimate effect using linear regression
        identified_estimand,
        method_name="backdoor.linear_regression"
    )
    refutation = model.refute_estimate( # Step 5: Refute estimate using placebo test
        identified_estimand,
        estimate,
        method_name="placebo_treatment_refuter"
    )
    return {
        "Treatment": treatment,
        "Causal Effect": round(estimate.value, 6),
        "Placebo Δ": round(refutation.new_effect - estimate.value, 6),
        "Refutation p-value": refutation.test_stat_significance if hasattr(refutation, "test_stat_significance") else "N/A"
    }

# Repeat execution
results = []
treatments = ['SMA_20', 'Low', 'High']
for t in treatments:
    others = [x for x in treatments if x != t]
    results.append(run_causal_analysis(t, others))

# Result
pd.DataFrame(results)
# Out:
#   Treatment  Causal Effect  Placebo Δ Refutation p-value
# 0    SMA_20      -0.017057   0.017057                N/A
# 1       Low       0.612724  -0.612724                N/A
# 2      High       0.407766  -0.407766                N/A

# %% [markdown]
# - **Treatment**: The manipulated variable (SMA_20, Low, High) for which we test causal impact on the outcome.
#
# - **Causal Effect**: The estimated average change in the outcome variable (Close) when the treatment variable increases by 1 unit, holding other variables constant.
#
# - **Placebo Δ**: The effect difference when the actual treatment variable is replaced with a random placebo variable.
# → A large difference suggests the original variable has a meaningful causal role.
#
# - **p-value (N/A)**: The refuter method used in this experiment does not provide a statistical p-value. Therefore, interpretation should focus on effect size and placebo comparison.
#
# ### 📌 Insights
# - **Low**:
#     - Shows the **strongest positive causal effect** among the features.
#
#     - A 1-unit increase in the Low price is associated with a significant increase in the next-day closing price.
#
#     - The large difference from the placebo estimate strengthens the credibility of this effect.
#
# - **High**:
#
#     - Also exhibits a **positive causal effect**, indicating that higher daily high prices tend to raise the closing price.
#
#     - The noticeable placebo gap suggests the effect is causally meaningful, not just correlated.
#
# - **SMA_20**:
#     - Shows a **small negative causal effect**: as the 20-day moving average increases, the predicted closing price slightly decreases.
#
#     - However, the effect is small and close to the placebo estimate, so the causal strength is likely weak or negligible.
#
# ## Interpreting PDP vs. Causal Learning Results
#
# ### 🔍 1. PDP (Partial Dependence Plot) vs. Causal Estimate (DoWhy)
# | Aspect            | PDP (SHAP-based)                               | Causal Estimate (DoWhy-based)                         |
# |------------------|-------------------------------------------------|------------------------------------------------------|
# | Methodology       | Observes average model response                | Estimates the potential outcome under intervention   |
# | Assumption        | Model-driven correlations                      | Backdoor adjustment for causal inference             |
# | Interpretation    | How the model learned to react to inputs       | What happens if we actually **intervene**            |
#
# ➡️ **PDP reflects the model's sensitivity**, while **causal estimates reveal real-world influence**.
#
# ---
#
# ### 🔍 2. Why SMA_20 Appears Strong in PDP but Weak in Causal Analysis
# - **SHAP + PDP** showed SMA_20 as highly influential in the model.
#   - This makes sense, as it summarizes recent price trends.
# - However, **SMA_20 is also derived from the close price itself**.
#   - From a causal standpoint, it's **not a manipulable cause**, but a **correlated outcome**.
#
# ---
#
# ### 🔍 3. Additional Considerations
# - **SMA_20** is a **lagging indicator** — it tracks trends rather than causes them.
# - **Low and High prices** reflect **real-time market activity** (demand/supply, investor behavior) and are thus more **causally relevant**.
#
# ---
#
# ### 🧠 Final Interpretation
# - A large gradient in the **PDP for SMA_20** suggests that the model finds it useful — but **not necessarily causal**.
# - In contrast, **causal analysis confirms that Low and High have meaningful influence**, while SMA_20 does not.

# %%
# Prepare Dataframe
causal_df = custom_df[['Open', 'Low', 'High', 'target_next_day']].dropna()
causal_df = causal_df.rename(columns={'target_next_day': 'Close'})

# Step 2: Define causal model iteratively
def run_causal_analysis(treatment, common_causes):
    model = CausalModel(
        data=causal_df,
        treatment=treatment,
        outcome='Close',
        common_causes=common_causes
    )
    identified_estimand = model.identify_effect() # Step 3: Identify causal effect
    estimate = model.estimate_effect( # Step 4: Estimate effect using linear regression
        identified_estimand,
        method_name="backdoor.linear_regression"
    )
    refutation = model.refute_estimate( # Step 5: Refute estimate using placebo test
        identified_estimand,
        estimate,
        method_name="placebo_treatment_refuter"
    )
    return {
        "Treatment": treatment,
        "Causal Effect": round(estimate.value, 6),
        "Placebo Δ": round(refutation.new_effect - estimate.value, 6),
        "Refutation p-value": refutation.test_stat_significance if hasattr(refutation, "test_stat_significance") else "N/A"
    }

# Repeat execution
results = []
treatments = ['Open', 'Low', 'High']
for t in treatments:
    others = [x for x in treatments if x != t]
    results.append(run_causal_analysis(t, others))

# Result
pd.DataFrame(results)
# Out:
#   Treatment  Causal Effect  Placebo Δ Refutation p-value
# 0      Open      -0.661726   0.661726                N/A
# 1       Low       0.897451  -0.897451                N/A
# 2      High       0.768461  -0.768461                N/A

# %% [markdown]
# - **Low and High prices have strong and positive causal effects** on the closing price, reinforcing their role as dominant signals in daily price formation.
#
# - **Open price shows a negative causal relationship**, which could imply a correction or reversal pattern throughout the trading day.
#
# - **Placebo Δ values are large for all three variables**, suggesting that the observed causal effects are not due to random noise or spurious correlations.
#
# - The placebo tests reinforce the credibility of our causal findings:
#
#     - **Low** and **High** prices have **strong and reliable positive effects** on the closing price.
#
#     - **Open** has a **consistent negative impact**, and the placebo confirms it is not a coincidental outcome.

# %% [markdown]
# CBA is a **stable long-term holding asset** that aligns well with **simple predictive models** and is therefore highly suitable for **conservative investors**.
#
# - The **Linear Regression (Custom)** model achieved the **highest R²**, indicating superior predictive accuracy.
# - In terms of financial metrics like **Sharpe Ratio** and **Cumulative Return**, NN-based models were not significantly better than the linear model.
#
#     - This suggests that even a simple model like Linear Regression can **predict CBA reliably and robustly**.
#
# - CBA shows a **steady upward monthly average price**, with **notable growth since 2023**.
# - Monthly volatility has **consistently decreased** since the COVID-19 shock in 2020, implying **increasing predictability and stability**.
#
#     - These traits strengthen the case for **long-term holding strategies** and reinforce its appeal to **risk-averse investors**.
#
# - **Low and High prices** exhibited **strong positive causal effects** on the closing price.
# - **Open** price, in contrast, showed a **significant negative causal effect**, meaning that higher opening prices trend to **lower the closing price**, potentially due to mean-reversion behavior or early overvaluation during the trading day.
# - **SMA_20**, while appearing important in SHAP-based interpretation, showed **little to no causal impact** when tested with formal causal inference (backdoor adjustment).
#
#     - While SHAP and PDP help us understand **how the model makes predictions**, causal learning tools like **DoWhy** reveal **what truly drives the closing price**.

# %% [markdown]
# 📌 **Takeaway**:
# For CBA:
# - **Simple models perform well**.
# - **Short-term price levels (Open, Low, High)** carry **more causal weight** than technical indicators.
# - CBA offers **high stability, low volatility**, and interpretability- ideal for **long-term conservative investors**.
